# %% [markdown]
# # Various IBD related Plots

# %%
import socket as socket
import os as os
import sys as sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
from matplotlib import gridspec

socket_name = socket.gethostname()
print(socket_name)

if socket_name.startswith("compute-"):
    print("HSM O2 Computational partition detected.")
    path = "/n/groups/reich/hringbauer/git/punic_aDNA//"  # The Path on Harvard Cluster
else: 
    raise RuntimeWarning("Not compatible machine. Check!!")

os.chdir(path)  # Set the right Path (in line with Atom default)
print(os.getcwd())

#sys.path.append("/n/groups/reich/hringbauer/git/hapBLOCK/python3/") 
#from main import HMM_Full
from ancIBD.run import hapBLOCK_chrom, run_plot_pair
#from plot.plot_posterior import plot_posterior, plot_posterior_panel
from ancIBD.plot.plot_karyotype import plot_karyo_from_ibd_df, plot_pde_individual_from_ibd_df
# Out:
# compute-a-16-171.o2.rc.hms.harvard.edu
# HSM O2 Computational partition detected.
# /n/groups/reich/hringbauer/git/punic_aDNA

# %% [markdown]
# ### Plot IBD in T774

# %%
post = run_plot_pair(iids=["I18201", "I18203"], ch=6, xlim=[], ms=2,
                     path_h5='/n/groups/reich/hringbauer/git/hapBLOCK/data/hdf5/1240k_v54.1/ch',
                     min_cm=4, plot=True, l_model="hdf5", max_gap=0.012,
                     p_col="variants/AF_ALL", folder_out="", output=False)
# Out:
# Filtering to 0.99 GP variants: 0.923x
# Filtering to 0.99 GP variants: 0.782x
# Filtering to common GP variants: 0.746x
# Plotting 75347 markers

# %% [markdown]
# ### Sicily - Kerkouene

# %%
post = run_plot_pair(iids=["I24213", "I12847"], ch=1, xlim=[], ms=2,
                     path_h5='/n/groups/reich/hringbauer/git/hapBLOCK/data/hdf5/1240k_v53.1/ch',
                     min_cm=4, plot=True, l_model="h5", e_model='haploid_gl', max_gap=0.012,
                     p_col="variants/AF_ALL", folder_out="", output=False)
# Out:
# Filtering to 0.99 GP variants: 0.884x
# Filtering to 0.99 GP variants: 0.899x
# Filtering to common GP variants: 0.822x
# Plotting 88408 markers

# %% [markdown]
# # IBD between Yamnaya Don and Afanesievo

# %%
post = run_plot_pair(iids=["I3951.SG", "I24086"], ch=4, xlim=[], ms=2,
                     path_h5='/n/groups/reich/hringbauer/git/hapBLOCK/data/hdf5/1240k_v53.1/ch',
                     min_cm=5, plot=True, l_model="h5", e_model='haploid_gl2', max_gap=0.012,
                     p_col="variants/AF_ALL", folder_out="", 
                     path_fig="./output/dumpster/I12847_I24213.karyo.png",
                     output=False)
# Out:
# Filtering to 0.99 GP variants: 0.989x
# Filtering to 0.99 GP variants: 0.924x
# Filtering to common GP variants: 0.916x
# Plotting 68518 markers
# Saved to ./output/dumpster/I12847_I24213.karyo.png

# %% [markdown]
# # Karyotype Plots

# %%
df_ibd = pd.read_csv("/n/groups/reich/hringbauer/git/ibd_euro/output/ibd/ibd220.ibd.v54.1.tsv", sep="\t")
print(f"Loaded {len(df_ibd)} IBD segments")
# Out:
# Loaded 3282060 IBD segments

# %% [markdown]
# ### Sicily - Kerkouene

# %%
### Sicily - Tunesia
plot_karyo_from_ibd_df(df_ibd, iids=["I12847", "I24213"], min_cm=8, 
                       savepath="./output/dumpster/I12847_I24213.karyo.pdf")
# Out:
# Found: 5 Pairs fitting in dataframe.
#
# Saved figure to ./output/dumpster/I12847_I24213.karyo.pdf

# %%
## Sicily - Tunesia
plot_karyo_from_ibd_df(df_ibd, iids=["I3951.SG", "I24086"], 
                       min_cm=6, savepath="./output/dumpster/I12847_I24213.karyo.pdf")
# Out:
# Found: 3 Pairs fitting in dataframe.
#
# Saved figure to ./output/dumpster/I12847_I24213.karyo.pdf

# %% [markdown]
# # T774 IBD

# %%
df_ibd2 = pd.read_csv(f"/n/groups/reich/hringbauer/git/punic_aDNA/output/ibd/v54.1.ch_all.tsv", sep="\t")

# %%
## Sicily - Tunesia
#I18199 I18200 I18203
plot_karyo_from_ibd_df(df_ibd2, iids=["I18199", "I18201"],
                       min_cm=12, savepath="./output/dumpster/I18199_I18201.karyo.pdf") # ./output/dumpster/I12847_I24213.karyo.pd
# Out:
# Found: 57 Pairs fitting in dataframe.
#
# Saved figure to ./output/dumpster/I18199_I18201.karyo.pdf

# %%
plot_karyo_from_ibd_df(df_ibd2, iids=["I18199", "I18203"], 
                       min_cm=12, savepath="./output/dumpster/I18199_I18203.karyo.pdf") # ./output/dumpster/I12847_I24213.karyo.pd
# Out:
# Found: 61 Pairs fitting in dataframe.
#
# Saved figure to ./output/dumpster/I18199_I18203.karyo.pdf

# %%
plot_karyo_from_ibd_df(df_ibd2, iids=["I18201", "I18203"], 
                       min_cm=12, savepath="./output/dumpster/I18201_I18203.karyo.pdf") # ./output/dumpster/I12847_I24213.karyo.pd
# Out:
# Found: 46 Pairs fitting in dataframe.
#
# Saved figure to ./output/dumpster/I18201_I18203.karyo.pdf

# %% [markdown]
# # Area 51
# Try out code here

# %%
df_target = give_sub_df(df_ibd, pop1=iid1, pop2=iid2, col="iid")
# Out:
# Found: 3 Pairs of Individuals with IBD stats.
