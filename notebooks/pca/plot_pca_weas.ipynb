# %% [markdown]
# # Code to run and plot PCA

# %%
import numpy as np
import os  # For Saving to Folder
import pandas as pd
import matplotlib.pyplot as plt

import socket
import os as os
import sys as sys
import multiprocessing as mp
import itertools as it
from time import time

# For Arial Font
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'   # Set the defaul
rcParams['font.sans-serif'] = ['Arial']

socket_name = socket.gethostname()
print(socket_name)

if socket_name.startswith("compute-"):
    print("HSM Computational partition detected.")
    path = "/n/groups/reich/hringbauer/git/punic_aDNA/"  # The Path on Midway Cluster
else:
    raise RuntimeWarning("Not compatible machine. Check!!")

os.chdir(path)  # Set the right Path (in line with Atom default)
# Show the current working directory. Should be HAPSBURG/Notebooks/ParallelRuns
print(os.getcwd())
print(f"CPU Count: {mp.cpu_count()}")
print(sys.version)
# Out:
# compute-a-16-134.o2.rc.hms.harvard.edu
# HSM Computational partition detected.
# /n/groups/reich/hringbauer/git/punic_aDNA
# CPU Count: 32
# 3.7.4 (default, Sep 11 2019, 11:24:51)
# [GCC 6.2.0]

# %%
def remove_individuals(df, remove_list=["_d"], iid_col="iid"):
    """Remove indivdiuals from PCA dataframe"""
    idx = df[iid_col].str.contains("|".join(remove_list))
    df = df[~idx].copy()
    print(f"Filtering to {len(df)}/{len(idx)}")
    return df

def get_sub_iid(df, pop_list=[""], iid_col="iid", output=True):
    """Remove indivdiuals from PCA dataframe"""
    pops = "|".join(pop_list)
    idx = df[iid_col].str.contains(pops)
    df = df[idx].copy()
    if output:
        print(f"{pops} IIDs: {len(df)}/{len(idx)}")
    return df

def get_sub_pops(df, pop_list=[], pop_col="pop"):
    """Get Sub Populations"""
    pops = "|".join(pop_list)
    idx = df[pop_col].str.contains(pops)
    df = df[idx].copy()
    print(f"{pops} Found: {len(df)}/{len(idx)}")
    return df

def get_sub_pops_exact(df, pop_list=[], pop_col="pop"):
    """Get Sub Populations"""
    idx = df[pop_col].isin(pop_list)
    df = df[idx].copy()
    print(f"Found {pop_list} (exact): {len(df)}/{len(idx)}")
    return df

def split_up_df(df, col="loc"):
    """Split up Dataframe by column.
    Return column labels and dataframes"""
    locs = [l for l, _ in df.groupby(col)]
    dfs = [df for _, df in df.groupby(col)]
    return locs, dfs

####################################################
### Plotting PCA

def plot_pca(ax, df, c="gray", alpha=1.0, legend="", marker="o",
             s=30, ec=None, text=False):
    """Plot PCA onto Axis"""
    ax.scatter(-df["pc1"], df["pc2"], c=c, alpha=alpha, label=legend, 
               ec=ec, s=s, marker=marker)
    if text:
        x, y = -df["pc1"].values, df["pc2"].values
        for i, txt in enumerate(df["iid"]):
            ax.annotate(txt, (x[i], y[i]), ha="left", va="bottom", c=c)
            
def plot_pca_ho(ax, df, c="gray", alpha=1.0, legend="", marker="o",
                s=30, ec=None, text=False):
    """Plot PCA onto Axis"""
    ax.scatter(-df["pc1"], df["pc2"], c=c, alpha=alpha, label=legend, 
               ec=ec, s=s, marker=marker)
    if text:
        x, y = -df["pc1"].values, df["pc2"].values
        for i, txt in enumerate(df["iid"]):
            ax.annotate(txt[:3], (x[i], y[i]), ha="center", va="center")   
            
###########################################################
### Helper Functions

def return_pca_matches(df, iid="I22119",
                       pcs = ["pc1", "pc2", "pc3", "pc4"]):
    """Return matches in pc space to sample iid.
    Report sorted dataframe"""
    pc_t = df[df["iid"]==iid][pcs]
    diffs = df[pcs]-pc_t.values
    diff_sq = np.sum(diffs**2,axis=1)
    idx = diff_sq.sort_values().index
    return df.iloc[idx,:].copy()

# %%
min_snp = 30000
#path_pca = "./output/pca/v46/20210317.punic1.v46_HO.construct_WE_NA_PCA.shrinkmodeNO.evec.txt"
#path_pca = "./output/pca/v45/20201116.punic1.v45_HO.construct_WE_NA_PCA.shrinkmode.evec.txt"
#path_pca = "./output/pca/v46/20210322.punic1.v46_HO.construct_WE_NA_PCA.smNO.outit.evec.txt"
path_pca = "./output/pca/v46/20210323.punic1.v46_HO.construct_WE_NA_PCA.smYES.outitY.evec.txt"
path_meta = "/n/groups/reich/hringbauer/Data/v46.3.anno.csv"

df = pd.read_csv(path_pca, 
                 sep=r"\s+", skiprows=1, header=None)
df.columns=["iid", "pc1", "pc2", "pc3", "pc4", "pop"]
df = remove_individuals(df, remove_list=["_d"])

df_meta = pd.read_csv(path_meta, sep=",")
df2 = df_meta[["iid", "Master ID", "loc", "n_cov_snp", 
               "mean_cov", "sex", "age", "contact"]]
df = pd.merge(df, df2, on="iid", how="left")
idx = (df["n_cov_snp"]<min_snp)
df = df[~idx]
df.loc[df["loc"].isnull(), "loc"]="not assigned"
print(f"Filtered to {len(df)} Individuals based on Min SNP: {min_snp}")

df = df.sort_values(by="n_cov_snp", ascending=False)
dup = (df["Master ID"].duplicated() & ~df["Master ID"].isnull())
df = df[~dup].copy().reset_index(drop=True)
print(f"Filtered to {len(df)} based on duplicates")

#df[df["pop"].str.contains("Lebanon")]
# Out:
# Filtering to 2144/2162
# Filtered to 2106 Individuals based on Min SNP: 30000
# Filtered to 2043 based on duplicates

# %% [markdown]
# ### Get PCA populations

# %%
df_ho = get_sub_pops_exact(df, pop_list=["construct_WE_NA_PCA"])
df_is = get_sub_pops_exact(df, pop_list=["Israel_MLBA"])
df_le = get_sub_pops_exact(df, pop_list=["Lebanon_MBA.SG"])
#df_isp = get_sub_pops_exact(df, pop_list=["Israel_Phoenician"])
df_isp = get_sub_pops(df, pop_list=["Israel_Phoenician"])

df_sard = get_sub_pops(df, pop_list=["Italy_Sardinia_Punic"])
df_sard_ba = get_sub_pops_exact(df, pop_list=["Italy_Sardinia_EBA","Italy_Sardinia_BA_Nuragic"])

df_tun = get_sub_pops(df, pop_list=["Tunisia_N"])
df_vil = get_sub_iid(df, ["VIL"])
df_msr = get_sub_iid(df, ["MSR"])

df_greek = get_sub_pops_exact(df, pop_list=["Greece_BA_Mycenaean"])
df_alg = get_sub_pops(df, pop_list=["Algeria_IA"])
df_spain = get_sub_pops_exact(df, pop_list=["Spain_IA"])

df_sic_mba = get_sub_pops_exact(df, pop_list=["Italy_Sicily_MBA"])

df_vill = get_sub_pops(df, pop_list=["Villaricos"], pop_col="loc")
df_vill = df_vill[(df_vill["pop"].str.contains("Punic")) & (df_vill["age"]>2000)]
df_ib = get_sub_pops(df, ["Ibiza_Punic"])
#df_sic = get_sub_pops_exact(df, ["Italy_Phoenician_Sicily"])
df_sic2 = get_sub_pops(df, ["Italy_Sicily_Punic"])
df_mar = df_sic2[df_sic2["loc"].str.contains("Marsala")].copy()
df_mot = df_sic2[df_sic2["loc"].str.contains("Motya")].copy()
df_bir = df_sic2[df_sic2["loc"].str.contains("Birgi")].copy()
df_sel = df_sic2[df_sic2["loc"].str.contains("Selinunte")].copy()
df_pal = df_sic2[df_sic2["loc"].str.contains("Palermo")].copy()

dft = get_sub_pops(df, ["Spain_Punic"])
df_cad = get_sub_pops(df, pop_list=["Cad"], pop_col="loc")


df_sic_ia = get_sub_pops_exact(df, ["Italy_Sicily_IA_Polizzello"])
df_sic_him = get_sub_pops(df, ["Sicily_Himera"])

df_eg_hell = get_sub_pops(df, ["Egypt_Hellenistic"])
df_eg_dyn = get_sub_pops(df, ["Egypt_Dynastic"])
df_meno = get_sub_pops(df, ["Menorca"])
df_kerk = get_sub_pops(df, ["Tunisia_Pun"])
# Out:
# Found ['construct_WE_NA_PCA'] (exact): 1196/2043
# Found ['Israel_MLBA'] (exact): 31/2043
# Found ['Lebanon_MBA.SG'] (exact): 5/2043
# Israel_Phoenician Found: 14/2043
# Italy_Sardinia_Punic Found: 20/2043
# Found ['Italy_Sardinia_EBA', 'Italy_Sardinia_BA_Nuragic'] (exact): 28/2043
# Tunisia_N Found: 9/2043
# VIL IIDs: 6/2043
# MSR IIDs: 2/2043
# Found ['Greece_BA_Mycenaean'] (exact): 13/2043
# Algeria_IA Found: 1/2043
# Found ['Spain_IA'] (exact): 21/2043
# Found ['Italy_Sicily_MBA'] (exact): 4/2043
# Villaricos Found: 13/2043
# Ibiza_Punic Found: 1/2043
# Italy_Sicily_Punic Found: 56/2043
# Spain_Punic Found: 14/2043
# Cad Found: 1/2043
# Found ['Italy_Sicily_IA_Polizzello'] (exact): 19/2043
# Sicily_Himera Found: 25/2043
# Egypt_Hellenistic Found: 2/2043
# Egypt_Dynastic Found: 2/2043
# Menorca Found: 1/2043
# Tunisia_Pun Found: 29/2043

# %%
dft = get_sub_pops(df, ["Spain_Punic"])
dft
# Out:
# Spain_Punic Found: 14/2043
#                   iid       pc1       pc2       pc3       pc4  \
# 84              I8135  0.018014 -0.019854 -0.001583 -0.003812
# 328            I18193 -0.045583 -0.050467 -0.053406 -0.047633
# 375            I18199 -0.009633 -0.008367  0.010012  0.003589
# 394            I18201 -0.008545 -0.010712  0.006593 -0.006274
# 430            I18203 -0.005214 -0.014029  0.009392 -0.004817
# 449            I18189 -0.031620 -0.042086 -0.027505 -0.024896
# 550            I26172  0.001447 -0.011412 -0.000246 -0.003167
# 568            I18191  0.000751 -0.022615  0.014663 -0.010750
# 631            I15434  0.019195 -0.014927 -0.002380 -0.015614
# 653   S18200.Y1.E2.L1 -0.007613 -0.020736  0.001862  0.017543
# 670            I12517  0.012247 -0.020672  0.006529 -0.004264
# 686            I18205 -0.008395 -0.024387 -0.001354 -0.029839
# 687            I18202 -0.006537 -0.008785  0.005073 -0.004806
# 2042  S18200.Y1.E3.L1 -0.004178 -0.021521  0.004245 -0.031025
#
#                                             pop Master ID  \
# 84                            Spain_Punic_Roman     I8135
# 328                       Spain_Punic_oAfrican2    I18193
# 375   Spain_Punic_o.3rd.degree.relative.cluster    I18199
# 394   Spain_Punic_o.3rd.degree.relative.cluster    I18201
# 430                              Spain_Punic_o4    I18203
# 449                       Spain_Punic_oAfrican2    I18189
# 550                        Spain_Punic_possible    I26172
# 568                Spain_Punic_Roman_oEuropean2    I18191
# 631                                 Spain_Punic    I15434
# 653                                 Spain_Punic    I18200
# 670                                 Spain_Punic    I12517
# 686                 Spain_Punic_Roman_oAfrican3    I18205
# 687   Spain_Punic_o.3rd.degree.relative.cluster    I18202
# 2042                                Spain_Punic       NaN
#
#                                            loc  n_cov_snp  mean_cov  sex  \
# 84        Cádiz, San Fernando, Campo de Hockey   879984.0  0.733320    F
# 328   Almería, Cuevas del Almazora, Villaricos   627577.0  0.522981    M
# 375   Almería, Cuevas del Almazora, Villaricos   538422.0  0.448685    M
# 394   Almería, Cuevas del Almazora, Villaricos   501006.0  0.417505    M
# 430   Almería, Cuevas del Almazora, Villaricos   436696.0  0.363913    F
# 449   Almería, Cuevas del Almazora, Villaricos   399759.0  0.333132    M
# 550                                     Malaga   223476.0  0.186230    F
# 568   Almería, Cuevas del Almazora, Villaricos   188166.0  0.156805    F
# 631            Cadiz, San Fernando, Torre Alta   113271.0  0.094392    F
# 653   Almería, Cuevas del Almazora, Villaricos    88896.0  0.074080    F
# 670               Cádiz, Solar Los Chinchorros    73598.0  0.061332    M
# 686   Almería, Cuevas del Almazora, Villaricos    60750.0  0.050625    F
# 687   Almería, Cuevas del Almazora, Villaricos    58646.0  0.048872    M
# 2042                              not assigned        NaN       NaN  NaN
#
#          age              contact
# 84    2050.0  Lalueza-Fox, Carles
# 328   2218.0  Lalueza-Fox, Carles
# 375   2226.0  Lalueza-Fox, Carles
# 394   2554.0  Lalueza-Fox, Carles
# 430   2225.0  Lalueza-Fox, Carles
# 449   2221.0  Lalueza-Fox, Carles
# 550   2301.0  Lalueza-Fox, Carles
# 568   1875.0  Lalueza-Fox, Carles
# 631   2100.0  Lalueza-Fox, Carles
# 653   1875.0  Lalueza-Fox, Carles
# 670   2450.0  Lalueza-Fox, Carles
# 686   1875.0  Lalueza-Fox, Carles
# 687   2350.0  Lalueza-Fox, Carles
# 2042     NaN                  NaN

# %% [markdown]
# ### HO PCA shrinkmode YES outlierremoval NO

# %%
#savepath="./figures/pca/west_med_punic_pca.pdf"
savepath=""
#savepath=""

df_ho = get_sub_pops_exact(df, pop_list=["construct_WE_NA_PCA"])
plt.figure(figsize=(8,8))
ax = plt.gca()

plot_pca_ho(ax, df_ho, c="lightgray", text=False)

if len(savepath) > 0:
    plt.savefig(savepath, bbox_inches = 'tight', 
                pad_inches = 0, dpi=600)
    print(f"Saved to: {savepath}")
    
plt.show()
# Out:
# Found ['construct_WE_NA_PCA'] (exact): 1196/2042

# %% [markdown]
# ### Without Removing outliers, v46

# %%
#savepath="./figures/pca/west_med_punic_pca.pdf"
savepath=""
#savepath=""

df_ho = get_sub_pops_exact(df, pop_list=["construct_WE_NA_PCA"])
plt.figure(figsize=(8,8))
ax = plt.gca()

plot_pca_ho(ax, df_ho, c="lightgray", text=False)

if len(savepath) > 0:
    plt.savefig(savepath, bbox_inches = 'tight', 
                pad_inches = 0, dpi=600)
    print(f"Saved to: {savepath}")
    
plt.show()
# Out:
# Found: 1196/2042

# %% [markdown]
# ### v45 PCA

# %%
#savepath="./figures/pca/west_med_punic_pca.pdf"
savepath=""
#savepath=""

df_ho = get_sub_pops_exact(df, pop_list=["construct_WE_NA_PCA"])
plt.figure(figsize=(8,8))
ax = plt.gca()

plot_pca_ho(ax, df_ho, c="lightgray", text=False)

if len(savepath) > 0:
    plt.savefig(savepath, bbox_inches = 'tight', 
                pad_inches = 0, dpi=600)
    print(f"Saved to: {savepath}")
    
plt.show()
# Out:
# Found: 1196/1989

# %% [markdown]
# ### V46 PCA

# %%
#savepath="./figures/pca/west_med_punic_pca.pdf"
savepath=""
#savepath=""

df_ho = get_sub_pops_exact(df, pop_list=["construct_WE_NA_PCA"])
plt.figure(figsize=(8,8))
ax = plt.gca()

plot_pca_ho(ax, df_ho, c="lightgray", text=False)

if len(savepath) > 0:
    plt.savefig(savepath, bbox_inches = 'tight', 
                pad_inches = 0, dpi=600)
    print(f"Saved to: {savepath}")
    
plt.show()
# Out:
# Found: 1132/1770

# %% [markdown]
# # Plot full PCA

# %%
#savepath="./figures/pca/west_med_punic_pca.pdf"
#savepath="./figures/pca.v46/west_med_punic_pca.pdf"
savepath="./figures/pca.v46/dated_marsala.pdf"
savepath=""

plt.figure(figsize=(8,8))
ax = plt.gca()

plot_pca_ho(ax, df_ho, c="lightgray", text=False)
plot_pca(ax, df_is, c="blue", legend="Israel Canaanite MLBA", ec="k", alpha=0.9)
plot_pca(ax, df_le, c="aqua", legend="Lebanon Canaanite MLBA", ec="k", alpha=0.9)

### Plot the Sardinian Samples
plot_pca(ax, df_sard_ba, c="lightgreen", legend="Sardinia BA", ec="k", s=40)
plot_pca(ax, df_tun, c="brown", legend="Tunisia N", ec="k", s=40)
plot_pca(ax, df_greek, c="gray", legend="Mycenean BA", ec="k", s=40)

plot_pca(ax, df_alg, c="k", legend="Algeria IA", s=40, ec="k")
plot_pca(ax, df_spain, c="green", legend="Spain IA", s=40, ec="k")

plot_pca(ax, df_sic_mba, c="lime", legend="Sicily Motya MBA", s=49, ec="k")
plot_pca(ax, df_sic_ia, c="orange", legend="Sicily Polizzello IA", s=49, ec="k")

plot_pca(ax, df_meno, c="gold", legend="Menorca LBA", ec="k", s=49)
plot_pca(ax, df_ib, c="red", legend="Ibiza Punic", ec="darkred", s=49, marker="D")

plot_pca(ax, df_vil, c="yellow", legend="Villamar Sardinian Punic", ec="darkred", s=49, marker="D")
plot_pca(ax, df_msr, c="pink", legend="Monte Sirai Sardinian Punic", ec="darkred", s=49, marker="D")

plot_pca(ax, df_sard, c="orange", legend="Tharros Sardinian Punic", ec="darkred", s=49, marker="s", text=True)

plot_pca(ax, df_vill, c="firebrick", legend="Villaricos Andalusia Punic", ec="darkred", s=49, marker="s", text=True)
plot_pca(ax, df_cad, c="lightcoral", legend="Cadiz Andalusia Punic", ec="darkred", s=49, marker="s", text=True)

plot_pca(ax, df_kerk, c="red", legend="Kerkouane Punic", ec="darkred", s=49, marker="s", text=False)

plot_pca(ax, df_eg_dyn, c="w", legend="Egypt Dynastic", ec="blue", s=40, marker="o")
plot_pca(ax, df_eg_hell, c="coral", legend="Egypt Hellenistic", ec="blue", s=40, marker="o")

plot_pca(ax, df_isp, c="darkviolet", legend="Israel Akzhiv Phoenician", ec="k", s=49, marker="s", alpha=0.9)

#plot_pca(ax, df_sic, c="w", legend="Sicilly Punic", ec="blue", s=70, marker="s")
#plot_pca(ax, df_sic2, c="coral", legend="Sicilly Punic2", ec="blue", s=70, marker="s")
#plot_pca(ax, df_sic_him, c="red", legend="Sicily Himera", s=90, marker="o", ec="k")

#plot_pca(ax, df_sic, c="k", legend="Sicilly Punic", ec="blue", s=70, marker=">")
#plot_pca(ax, df_sic2, c="coral", legend="Sicilly Punic2", ec="blue", s=70, marker=">")


df_iid = get_sub_iid(df, ["I4800", "I22232", "I22236", "I4798", "I4799"])

plot_pca(ax, df_iid, c="lightblue", legend="Motya Early (700-400 calBCE)", ec="k", s=80, marker="o")

df_iid = get_sub_iid(df, ["I12844"])
plot_pca(ax, df_iid, c="blue", legend="Motya Late (350-50 calBCE)", ec="k", s=80, marker="o")

df_iid = get_sub_iid(df, ["I8577|I7454"])
plot_pca(ax, df_iid, c="black", legend="Marsala Late (350-50 calBCE)", ec="k", s=80, marker="o")

df_iid = get_sub_iid(df, ["I12849|I7265"])
plot_pca(ax, df_iid, c="darkblue", legend="Marsala Roman (100-300 calCE)", ec="k", s=80, marker="o")

#df_iid = get_sub_iid(df, ["I21971"])
#plot_pca(ax, df_iid, c="gray", legend="Marsala Punic Context", ec="k", s=80, marker="o")

ax.legend(loc="upper right", fontsize=9)
ax.set_xlabel("PC 1")
ax.set_ylabel("PC 2")
#ax.set_xlim([-0.035,0.085])
#ax.set_ylim([-0.07,0.034])

ax.set_xlim([-0.0,0.085])
ax.set_ylim([-0.07,0])

if len(savepath) > 0:
    plt.savefig(savepath, bbox_inches = 'tight', 
                pad_inches = 0, dpi=600)
    print(f"Saved to: {savepath}")
    
plt.show()
# Out:
# I4800|I22232|I22236|I4798|I4799 IIDs: 5/2043
# I12844 IIDs: 1/2043
# I8577|I7454 IIDs: 2/2043
# I12849|I7265 IIDs: 2/2043

# %%
df_vil.sort_values(by="pc2")
# Out:
#         iid       pc1       pc2       pc3       pc4  \
# 470  VIL011 -0.020347 -0.036925 -0.012824 -0.023513
# 412  VIL006 -0.014099 -0.033446 -0.008456 -0.030796
# 663  VIL009 -0.012079 -0.029161 -0.007052 -0.026737
# 579  VIL010 -0.017920 -0.028757 -0.008581 -0.015689
# 421  VIL007 -0.011331 -0.026037 -0.003551 -0.015784
# 689  VIL004 -0.008030 -0.014609  0.005240  0.003087
#
#                            pop Master ID                     loc  n_cov_snp  \
# 470  Italy_Sardinia_IA_Punic_1    VIL011  Villamar, VS, Villamar   366554.0
# 412  Italy_Sardinia_IA_Punic_1    VIL006  Villamar, VS, Villamar   468529.0
# 663  Italy_Sardinia_IA_Punic_1    VIL009  Villamar, VS, Villamar    77589.0
# 579  Italy_Sardinia_IA_Punic_1    VIL010  Villamar, VS, Villamar   173540.0
# 421  Italy_Sardinia_IA_Punic_1    VIL007  Villamar, VS, Villamar   450084.0
# 689  Italy_Sardinia_IA_Punic_2    VIL004  Villamar, VS, Villamar    55509.0
#
#      mean_cov sex     age        contact
# 470  0.305462   M  2754.0  John Novembre
# 412  0.390441   F  2622.0  John Novembre
# 663  0.064658   F  2400.0  John Novembre
# 579  0.144617   F  2741.0  John Novembre
# 421  0.375070   M  2409.0  John Novembre
# 689  0.046258   F  2381.0  John Novembre

# %% [markdown]
# # Plot Single Samples

# %%
def plot_pca_sample(iid, savepath="", show=True, xy=[]):
    """Plot PCA of a single new individual"""
    #savepath=""

    plt.figure(figsize=(8,8))
    ax = plt.gca()

    plot_pca_ho(ax, df_ho, c="lightgray", text=False) # HO Reference
    
    plot_pca(ax, df_is, c="blue", legend="Israel Canaanite MLBA", ec="k", alpha=0.9)
    plot_pca(ax, df_le, c="aqua", legend="Lebanon Canaanite MLBA", ec="k", alpha=0.9)
    plot_pca(ax, df_sard_ba, c="lightgreen", legend="Sardinia BA", ec="k", s=40)
    plot_pca(ax, df_tun, c="brown", legend="Tunisia N", ec="k", s=40)
    plot_pca(ax, df_greek, c="gray", legend="Mycenean BA", ec="k", s=40)
    plot_pca(ax, df_alg, c="k", legend="Algeria IA", s=40, ec="k")
    plot_pca(ax, df_spain, c="green", legend="Spain IA", s=40, ec="k")
    plot_pca(ax, df_sic_mba, c="lime", legend="Sicily Motya MBA", s=49, ec="k")
    plot_pca(ax, df_sic_ia, c="orange", legend="Sicily Polizzello IA", s=49, ec="k")
    plot_pca(ax, df_meno, c="gold", legend="Menorca LBA", ec="k", s=49)
    
    plot_pca(ax, df_kerk, c="rosybrown", legend="Kerkouane Punic", ec="darkred", s=49, marker="s", text=False)
    plot_pca(ax, df_ib, c="red", legend="Ibiza Punic", ec="darkred", s=49, marker="D")
    plot_pca(ax, df_vil, c="yellow", legend="Villamar Sardinian Punic", ec="darkred", s=49, marker="D")
    plot_pca(ax, df_msr, c="pink", legend="Monte Sirai Sardinian Punic", ec="darkred", s=49, marker="D")
    plot_pca(ax, df_sard, c="orange", legend="Tharros Sardinian Punic", ec="darkred", s=49, marker="s", text=False)
    plot_pca(ax, df_vill, c="firebrick", legend="Villaricos Andalusia Punic", ec="darkred", s=49, marker="s", text=False)
    plot_pca(ax, df_cad, c="lightcoral", legend="Cadiz Andalusia Punic", ec="darkred", s=49, marker="s", text=False)
    plot_pca(ax, df_eg_dyn, c="w", legend="Egypt Dynastic", ec="blue", s=40, marker="o")
    plot_pca(ax, df_eg_hell, c="coral", legend="Egypt Hellenistic", ec="blue", s=40, marker="o")
    plot_pca(ax, df_isp, c="darkviolet", legend="Israel Akzhiv Phoenician", ec="k", s=49, marker="s", alpha=0.9)

    df_iid = get_sub_iid(df, ["I4800", "I22232", "I22236", "I4798", "I4799"], output=False)
    plot_pca(ax, df_iid, c="lightblue", legend="Motya Early (700-400 calBCE)", ec="k", s=80, marker="o")

    df_iid = get_sub_iid(df, ["I12844"], output=False)
    plot_pca(ax, df_iid, c="blue", legend="Motya Late (350-50 calBCE)", ec="k", s=80, marker="o")

    df_iid = get_sub_iid(df, ["I8577|I7454"], output=False)
    plot_pca(ax, df_iid, c="black", legend="Marsala Late (350-50 calBCE)", ec="k", s=80, marker="o")

    df_iid = get_sub_iid(df, ["I12849|I7265"], output=False)
    plot_pca(ax, df_iid, c="darkblue", legend="Marsala Roman (100-300 calCE)", ec="k", s=80, marker="o")

    
    df_iid = get_sub_iid(df, iid)
    plot_pca(ax, df_iid, c="red", legend=iid[0], ec="k", s=120, marker="X")

    #df_iid = get_sub_iid(df, ["I21971"], output=False)
    #plot_pca(ax, df_iid, c="gray", legend="Marsala Punic Context", ec="k", s=80, marker="o")

    ax.legend(loc="upper right", fontsize=9)
    ax.set_xlabel("PC 1")
    ax.set_ylabel("PC 2")
    ax.set_xlim([-0.035,0.085])
    ax.set_ylim([-0.07,0.034])
    
    if len(xy)>0:
        iid = df_iid["iid"].values[0]
        depth, age = df_iid["n_cov_snp"].values[0].astype("int"), df_iid["age"].values[0].astype("int")
        text = f"{iid}:\n{depth:.0f} SNPs\n{age:.0f} BP"
        ax.text(xy[0], xy[1], text, ha='left', va='bottom', transform=ax.transAxes)
    
    if len(savepath) > 0:
        plt.savefig(savepath, bbox_inches = 'tight', 
                    pad_inches = 0, dpi=600)
        print(f"Saved to: {savepath}")
    if show:
        plt.show()

# %%
df.sort_values(by="pc2")[:50]

# %%
plot_pca_sample(iid=["I12848"], savepath="") # Caramelli Phoenician: I22232 I22235 I22236
# Out:
# I12848 IIDs: 1/2043

# %%
iids_afr_punic =  ["I18193", "I18189", "I22093"]  # "I22113" high but not high enough
iids_afr_cline = ["I21966", "I21984", "I22094", "I22090", "VIL011", "VIL006", "VIL009", "VIL010", "VIL007"] # but not VIL004

# %%
plot_pca_sample(iid=iids_afr_cline, savepath="") # Caramelli Phoenician: I22232 I22235 I22236
# Out:
# I21966|I21984|I22094|I22090|VIL011|VIL006|VIL009|VIL010|VIL007 IIDs: 9/2043

# %% [markdown]
# ### Plot and safe all Individual Punic Samples
# Runs about 2 min for Sicily Sample

# %%
#df_plot = get_sub_pops(df, ["Italy_Sicily_Roman"])
#df_plot = get_sub_pops(df, pop_list=["Italy_Sardinia_Punic"])
df_vill = get_sub_pops(df, pop_list=["Villaricos"], pop_col="loc")
df_plot = df_vill[(df_vill["pop"].str.contains("Punic")) & (df_vill["age"]>2000)]


for iid in df_plot["iid"].values:
    savepath = f"/n/groups/reich/hringbauer/git/punic_aDNA/figures/pca.v46/villaricos_inds/{iid}.pdf"
    plot_pca_sample(iid=[iid], savepath=savepath, xy=[0.01,0.01], show=False) # Caramelli Phoenician: I22232 I22235 I22236

# %%
df_alg
# Out:
#         iid       pc1       pc2       pc3       pc4         pop Master ID  \
# 217  I12433 -0.047247 -0.055366 -0.055142 -0.054335  Algeria_IA    I12433
#
#                                     loc  n_cov_snp  mean_cov sex     age  \
# 217  Aurès, Constantine, Khenchela Cave   757025.0  0.630854   F  2752.0
#
#           contact
# 217  Pinhasi, Ron

# %% [markdown]
# ### Dated Motya Sample, context 6th century BCE, local Sicilian ancestry

# %%
plot_pca_sample(iid=["I12665|I21856|I24554|I22000"], savepath="") # Caramelli Phoenician: I22232 I22235 I22236
# Out:
# I4800|I22232|I22236|I4798|I4799 IIDs: 5/2042
# I12844 IIDs: 1/2042
# I8577|I7454 IIDs: 2/2042
# I12849|I7265 IIDs: 2/2042
# I12665|I21856|I24554|I22000 IIDs: 4/2042

# %% [markdown]
# ### Plot single Ancient Individual

# %%
plot_pca_sample(iid=["I12666"], savepath="", xy=[0.01,0.01])
# Out:
# I4800|I22232|I22236|I4798|I4799 IIDs: 5/2043
# I12844 IIDs: 1/2043
# I8577|I7454 IIDs: 2/2043
# I12849|I7265 IIDs: 2/2043
# I12666 IIDs: 1/2043

# %% [markdown]
# # Marsala by contributor

# %%
#savepath="./figures/pca/west_med_punic_pca.pdf"
#savepath="./figures/pca.v46/tharros.pdf"
savepath="./figures/pca.v46/marsala.pdf"

plt.figure(figsize=(8,8))
ax = plt.gca()

plot_pca_ho(ax, df_ho, c="lightgray", text=False)
plot_pca(ax, df_is, c="blue", legend="Israel Canaanite MLBA", ec="k", alpha=0.9)
#plot_pca(ax, df_le, c="aqua", legend="Lebanon Canaanite MLBA", ec="k", alpha=0.9)
plot_pca(ax, df_isp, c="darkviolet", legend="Israel \"Phoenician\"", ec="k", alpha=0.9)
### Plot the Sardinian Samples
#plot_pca(ax, df_sard_ba, c="lightgreen", legend="Sardinia BA", ec="k", s=40)

plot_pca(ax, df_sard, c="gray", legend="Non-Sicily Punic", ec="k", s=49, marker="o", text=False, alpha=0.9)
#plot_pca(ax, df_sard1, c="orange", legend="Tharros Sardinian Roman/Punic", ec="red", s=49, marker="s", text=False)

plot_pca(ax, df_vill, c="gray", legend="", ec="gray", s=49, marker="o", text=False)
plot_pca(ax, df_cad, c="gray", legend="", ec="gray", s=49, marker="o", text=False)
plot_pca(ax, df_kerk, c="gray", legend="", ec="gray", s=49, marker="o", text=False)



plot_pca(ax, df_tun, c="brown", legend="Tunisia N", ec="k", s=40)
plot_pca(ax, df_greek, c="gray", legend="Mycenean BA", ec="k", s=40)

#plot_pca(ax, df_alg, c="k", legend="Algeria IA", s=40, ec="k")
plot_pca(ax, df_spain, c="green", legend="Spain IA", s=40, ec="k")

plot_pca(ax, df_sic_ia, c="orange", legend="Sicily Polizzello IA", s=49, ec="k")
#plot_pca(ax, df_meno, c="gold", legend="Menorca LBA", ec="k", s=49)

#plot_pca(ax, df_ib, c="red", legend="Ibiza Punic", ec="darkred", s=49, marker="D")
#plot_pca(ax, df_vil, c="yellow", legend="Villamar Sardinian Punic", ec="darkred", s=49, marker="D")
#plot_pca(ax, df_msr, c="pink", legend="Monte Sirai Sardinian Punic", ec="darkred", s=49, marker="D")

### Plot the Re
plot_pca(ax, df_mot, c="k", legend="Motya, Sicily Punic", ec="k", s=60, marker="s", text=False)
#plot_pca(ax, df_mar, c="green", legend="Marsala, Sicily Punic", ec="k", s=90, marker="o", text=False)

df_sin = df_mar[df_mar["contact"].str.contains("Sineo")]
df_gron = df_mar[df_mar["contact"].str.contains("Gronau")]
df_luis = df_mar[df_mar["contact"].str.contains("Luiselli")]

plot_pca(ax, df_sin, c="red", legend="Marsala Punic, Sineo", ec="k", s=60, marker="s", text=False)
plot_pca(ax, df_gron, c="yellow", legend="Marsala Punic, Gronau", ec="k", s=60, marker="s", text=False)
plot_pca(ax, df_luis, c="pink", legend="Marsala Punic, Luiselli", ec="k", s=60, marker="s", text=False)
plot_pca(ax, df_bir, c="gray", legend="Birgi Punic, Gronau", ec="k", s=60, marker="s", text=False)

plot_pca(ax, df_sel, c="white", legend="Selinunte Punic, Gronau", ec="k", s=60, marker="s", text=False)


plot_pca(ax, df_sic_ia, c="orange", legend="Sicily Polizzello IA", s=49, ec="k")

ax.legend(loc="upper right", fontsize=9)
ax.set_xlabel("PC 1")
ax.set_ylabel("PC 2")
ax.set_xlim([-0.035,0.08])
ax.set_ylim([-0.07,0.035])

if len(savepath) > 0:
    plt.savefig(savepath, bbox_inches = 'tight', 
                pad_inches = 0, dpi=600)
    print(f"Saved to: {savepath}")
    
plt.show()
# Out:
# Saved to: ./figures/pca.v46/marsala.pdf

# %% [markdown]
# # Extract Punic Individual by cline

# %%
df_mar["contact"].value_counts()
# Out:
# Gronau, Ilan        13
# Sineo, Luca          7
# Luiselli, Donata     4
# Name: contact, dtype: int64

# %% [markdown]
# # Highlight Consanguineous Individuals

# %%
#savepath="./figures/pca/west_med_punic_pca.pdf"
iid = "I24041|I24190|I24045|I24196|I24193"
iid2 = "I22121|I22119|I21964"
iid3 = "I18199|I18201|I18203"
savepath=f"./figures/pca.v45/consagnuineous_pca.pdf"
savepath=""

df_iid = get_sub_iid(df, [iid])
df_iid2 = get_sub_iid(df, [iid2])
df_iid3 = get_sub_iid(df, [iid3])

plt.figure(figsize=(8,8))
ax = plt.gca()

plot_pca_ho(ax, df_ho, c="lightgray", text=False)
plot_pca(ax, df_is, c="blue", legend="Israel Canaanite MLBA", ec="k", alpha=0.9)
#plot_pca(ax, df_le, c="aqua", legend="Lebanon Canaanite MLBA", ec="k", alpha=0.9)
plot_pca(ax, df_isp, c="darkviolet", legend="Israel \"Phoenician\"", ec="k", alpha=0.9)
### Plot the Sardinian Samples
plot_pca(ax, df_sard_ba, c="lightgreen", legend="Sardinia BA", ec="k", s=40)
plot_pca(ax, df_tun, c="brown", legend="Tunisia N", ec="k", s=40)
plot_pca(ax, df_greek, c="gray", legend="Mycenean BA", ec="k", s=40)

plot_pca(ax, df_alg, c="k", legend="Algeria IA", s=40, ec="k")
plot_pca(ax, df_spain, c="green", legend="Spain IA", s=40, ec="k")

plot_pca(ax, df_sic_ia, c="orange", legend="Sicily Polizzello IA", s=49, ec="k")


plot_pca(ax, df_meno, c="gold", legend="Menorca LBA", ec="k", s=49)
plot_pca(ax, df_ib, c="red", legend="Ibiza Punic", ec="darkred", s=49, marker="D")

plot_pca(ax, df_vil, c="yellow", legend="Villamar Sardinian Punic", ec="darkred", s=49, marker="D")
plot_pca(ax, df_msr, c="pink", legend="Monte Sirai Sardinian Punic", ec="darkred", s=49, marker="D")

plot_pca(ax, df_sard, c="orange", legend="Tharros Sardinian Punic", ec="darkred", s=49, marker="s", text=False)
#plot_pca(ax, df_sard1, c="orange", legend="Tharros Sardinian Roman/Punic", ec="red", s=49, marker="s", text=False)

plot_pca(ax, df_vill, c="firebrick", legend="Villaricos Andalusia Punic", ec="darkred", s=49, marker="s", text=False)
plot_pca(ax, df_cad, c="lightcoral", legend="Cadiz Andalusia Punic", ec="darkred", s=49, marker="s", text=False)

plot_pca(ax, df_kerk, c="red", legend="Kerkouane Punic", ec="darkred", s=49, marker="s", text=False)
plot_pca(ax, df_iid, c="cyan", legend=f"Kerkouane Consanguineous", ec="k", alpha=0.95, s=100)
plot_pca(ax, df_iid2, c="pink", legend=f"Tharros Consanguineous", ec="k", alpha=0.95, s=100)
plot_pca(ax, df_iid3, c="lime", legend=f"Villariocs Consanguineous", ec="k", alpha=0.95, s=100)

ax.legend(loc="upper right", fontsize=9)
ax.set_xlabel("PC 1")
ax.set_ylabel("PC 2")
ax.set_xlim([-0.035,0.08])
ax.set_ylim([-0.07,0.035])

if len(savepath) > 0:
    plt.savefig(savepath, bbox_inches = 'tight', 
                pad_inches = 0, dpi=600)
    print(f"Saved to: {savepath}")
    
plt.show()
# Out:
# Found: 5/2042
# Found: 3/2042
# Found: 3/2042

# %% [markdown]
# # Plot single individual

# %%
#savepath="./figures/pca/west_med_punic_pca.pdf"
iid = "I12847|I24213"  ### Tunisia - Sicilly relative!
#iid = "I22122|I22118|I22117"  # Relatives Tharros
#iid = "I22122"
#savepath=f"./figures/pca.v45/kerkouane_ROH_pca.pdf"
savepath=""

df_iid = get_sub_iid(df, [iid])

plt.figure(figsize=(8,8))
ax = plt.gca()

plot_pca_ho(ax, df_ho, c="lightgray", text=False)
plot_pca(ax, df_is, c="blue", legend="Israel Canaanite MLBA", ec="k", alpha=0.9)
#plot_pca(ax, df_le, c="aqua", legend="Lebanon Canaanite MLBA", ec="k", alpha=0.9)
plot_pca(ax, df_isp, c="darkviolet", legend="Israel \"Phoenician\"", ec="k", alpha=0.9)
### Plot the Sardinian Samples
plot_pca(ax, df_sard_ba, c="lightgreen", legend="Sardinia BA", ec="k", s=40)
plot_pca(ax, df_tun, c="brown", legend="Tunisia N", ec="k", s=40)
plot_pca(ax, df_greek, c="gray", legend="Mycenean BA", ec="k", s=40)

plot_pca(ax, df_alg, c="k", legend="Algeria IA", s=40, ec="k")
plot_pca(ax, df_spain, c="green", legend="Spain IA", s=40, ec="k")

plot_pca(ax, df_sic_ia, c="orange", legend="Sicily Polizzello IA", s=49, ec="k")


plot_pca(ax, df_meno, c="gold", legend="Menorca LBA", ec="k", s=49)
plot_pca(ax, df_ib, c="red", legend="Ibiza Punic", ec="darkred", s=49, marker="D")

plot_pca(ax, df_vil, c="yellow", legend="Villamar Sardinian Punic", ec="darkred", s=49, marker="D")
plot_pca(ax, df_msr, c="pink", legend="Monte Sirai Sardinian Punic", ec="darkred", s=49, marker="D")

plot_pca(ax, df_sard, c="orange", legend="Tharros Sardinian Punic", ec="darkred", s=49, marker="s", text=False)

plot_pca(ax, df_vill, c="firebrick", legend="Villaricos Andalusia Punic", ec="darkred", s=49, marker="s", text=False)
plot_pca(ax, df_cad, c="lightcoral", legend="Cadiz Andalusia Punic", ec="darkred", s=49, marker="s", text=False)

plot_pca(ax, df_kerk, c="red", legend="Kerkouane Punic", ec="darkred", s=49, marker="s", text=False)
plot_pca(ax, df_iid, c="cyan", legend=f"{iid}", ec="k", alpha=0.95, s=100)

ax.legend(loc="upper right", fontsize=9)
ax.set_xlabel("PC 1")
ax.set_ylabel("PC 2")
ax.set_xlim([-0.035,0.08])
ax.set_ylim([-0.07,0.035])

if len(savepath) > 0:
    plt.savefig(savepath, bbox_inches = 'tight', 
                pad_inches = 0, dpi=600)
    print(f"Saved to: {savepath}")
    
plt.show()
# Out:
# I12847|I24213 IIDs: 2/2042

# %%
df_vill.sort_values(by="pc2")

# %%
#savepath="./figures/pca/west_med_punic_pca.pdf"
iid = "I22121"
#savepath=f"./figures/pca.v45/kerkouane_ROH_pca.pdf"
savepath=""

df_iid = get_sub_iid(df, [iid])

plt.figure(figsize=(8,8))
ax = plt.gca()

plot_pca_ho(ax, df_ho, c="lightgray", text=False)
plot_pca(ax, df_is, c="blue", legend="Israel Canaanite MLBA", ec="k", alpha=0.9)
#plot_pca(ax, df_le, c="aqua", legend="Lebanon Canaanite MLBA", ec="k", alpha=0.9)
plot_pca(ax, df_isp, c="darkviolet", legend="Israel \"Phoenician\"", ec="k", alpha=0.9)
### Plot the Sardinian Samples
plot_pca(ax, df_sard_ba, c="lightgreen", legend="Sardinia BA", ec="k", s=40)
plot_pca(ax, df_tun, c="brown", legend="Tunisia N", ec="k", s=40)
plot_pca(ax, df_greek, c="gray", legend="Mycenean BA", ec="k", s=40)

plot_pca(ax, df_alg, c="k", legend="Algeria IA", s=40, ec="k")
plot_pca(ax, df_spain, c="green", legend="Spain IA", s=40, ec="k")

plot_pca(ax, df_sic_ia, c="orange", legend="Sicily Polizzello IA", s=49, ec="k")



plot_pca(ax, df_meno, c="gold", legend="Menorca LBA", ec="k", s=49)
plot_pca(ax, df_ib, c="red", legend="Ibiza Punic", ec="darkred", s=49, marker="D")

plot_pca(ax, df_vil, c="yellow", legend="Villamar Sardinian Punic", ec="darkred", s=49, marker="D")
plot_pca(ax, df_msr, c="pink", legend="Monte Sirai Sardinian Punic", ec="darkred", s=49, marker="D")

plot_pca(ax, df_sard, c="orange", legend="Tharros Sardinian Punic", ec="darkred", s=49, marker="s", text=False)
plot_pca(ax, df_sard1, c="orange", legend="Tharros Sardinian Roman/Punic", ec="red", s=49, marker="s", text=False)

plot_pca(ax, df_vill, c="firebrick", legend="Villaricos Andalusia Punic", ec="darkred", s=49, marker="s", text=False)
plot_pca(ax, df_cad, c="lightcoral", legend="Cadiz Andalusia Punic", ec="darkred", s=49, marker="s", text=False)

plot_pca(ax, df_kerk, c="red", legend="Kerkouane Punic", ec="darkred", s=49, marker="s", text=False)
plot_pca(ax, df_iid, c="cyan", legend=f"{iid}", ec="k", alpha=0.95, s=100)

ax.legend(loc="upper right", fontsize=9)
ax.set_xlabel("PC 1")
ax.set_ylabel("PC 2")
ax.set_xlim([-0.035,0.08])
ax.set_ylim([-0.07,0.035])

if len(savepath) > 0:
    plt.savefig(savepath, bbox_inches = 'tight', 
                pad_inches = 0, dpi=600)
    print(f"Saved to: {savepath}")
    
plt.show()

# %%
df_kerk.sort_values(by="pc2")

# %% [markdown]
# # Sicilian Punic

# %%
savepath="./figures/pca.v46/pca_sicilly_punic.png"
savepath=""

plt.figure(figsize=(8,8))
ax = plt.gca()

plot_pca(ax, df_ho, c="lightgray")

plot_pca(ax, df_is, c="blue", legend="Israel Canaanite MLBA", ec="k", alpha=0.9)
#plot_pca(ax, df_le, c="aqua", legend="Lebanon Canaanite MLBA", ec="k", alpha=0.9)
plot_pca(ax, df_isp, c="darkviolet", legend="Israel \"Phoenician\"", ec="k", alpha=0.9)
### Plot the Sardinian Samples
#plot_pca(ax, df_sard_ba, c="lightgreen", legend="Sardinia BA", ec="k", s=40)
plot_pca(ax, df_tun, c="brown", legend="Tunisia N", ec="k", s=40)
plot_pca(ax, df_greek, c="gray", legend="Mycenean BA", ec="k", s=40)

plot_pca(ax, df_alg, c="k", legend="Algeria IA", s=40, marker="s", ec="k")
plot_pca(ax, df_spain, c="green", legend="Spain IA", s=40, ec="k")
plot_pca(ax, df_sic_ia, c="orange", legend="Sicily Polizzello IA", s=40, ec="k")

plot_pca(ax, df_eg_dyn, c="w", legend="Egypt Dynastic", ec="blue", s=40, marker="o")
plot_pca(ax, df_eg_hell, c="coral", legend="Egypt Hellenistic", ec="blue", s=40, marker="o")

#plot_pca(ax, df_sard, c="orange", legend="Tharros Sardinian Punic", ec="darkred", s=50, marker="s")
#plot_pca(ax, df_vil, c="yellow", legend="Villamar Sardinian Punic", ec="darkred", s=50, marker="s")
#plot_pca(ax, df_msr, c="maroon", legend="Monte Sirai Sardinian Punic", ec="darkred", s=50, marker="s")

#plot_pca(ax, df_vill, c="red", legend="Andalusia Villaricos Punic", ec="darkred", s=50, marker="D")
#plot_pca(ax, df_ib, c="red", legend="Ibiza Punic", ec="sandybrown", s=70, marker="*")

#plot_pca(ax, df_sic, c="w", legend="Sicilly Punic", ec="blue", s=70, marker="s")
plot_pca(ax, df_vil, c="yellow", legend="Villamar Sardinian Punic", ec="darkred", s=49, marker="D")
plot_pca(ax, df_msr, c="pink", legend="Monte Sirai Sardinian Punic", ec="darkred", s=49, marker="D")

plot_pca(ax, df_sard, c="orange", legend="Tharros Sardinian Punic", ec="darkred", s=49, marker="s", text=False)

plot_pca(ax, df_vill, c="firebrick", legend="Villaricos Andalusia Punic", ec="darkred", s=49, marker="s", text=False)
plot_pca(ax, df_cad, c="lightcoral", legend="Cadiz Andalusia Punic", ec="darkred", s=49, marker="s", text=False)
plot_pca(ax, df_kerk, c="red", legend="Kerkouane Punic", ec="darkred", s=49, marker="s", text=False)


plot_pca(ax, df_sic_him, c="lime", legend="Sicily Himera", s=90, marker="o", ec="k")
plot_pca(ax, df_sic2, c="green", legend="Sicilly Punic", ec="k", s=70, marker="s")


ax.legend(loc="upper right", fontsize=8)
ax.set_xlabel("PC 1")
ax.set_ylabel("PC 2")
ax.set_xlim([-0.035,0.08])
ax.set_ylim([-0.06,0.032])

if len(savepath) > 0:
    plt.savefig(savepath, bbox_inches = 'tight', 
                pad_inches = 0, dpi=600)
    print(f"Saved to: {savepath}")
    
plt.show()

# %%
df_meta[df_meta["clst"].str.contains("Phoen")].sort_values(by="age")

# %% [markdown]
# ### Sicilly by Site

# %%
savepath="./figures/pca.v46/pca_sicilly_punic.png"
savepath = "./figures/pca.v46/pca_sicilly_punic.pdf"
savepath = ""

plt.figure(figsize=(8,8))
ax = plt.gca()

plot_pca(ax, df_ho, c="lightgray")

plot_pca(ax, df_is, c="blue", legend="Israel Canaanite MLBA", ec="k", alpha=0.9)
plot_pca(ax, df_le, c="aqua", legend="Lebanon MBA", ec="k", alpha=0.9)
plot_pca(ax, df_isp, c="darkviolet", legend="Israel \"Phoenician\"", ec="k", alpha=0.9)
### Plot the Sardinian Samples
#plot_pca(ax, df_sard_ba, c="lightgreen", legend="Sardinia BA", ec="k", s=40)
plot_pca(ax, df_tun, c="brown", legend="Tunisia N", ec="k", s=40)
plot_pca(ax, df_greek, c="gray", legend="Mycenean BA", ec="k", s=40)

plot_pca(ax, df_alg, c="k", legend="Algeria IA", s=40, marker="s", ec="k")
plot_pca(ax, df_spain, c="green", legend="Spain IA", s=40, ec="k")
plot_pca(ax, df_sic_ia, c="orange", legend="Sicily Polizzello IA", s=40, ec="k")

plot_pca(ax, df_eg_dyn, c="w", legend="Egypt Dynastic", ec="blue", s=40, marker="o")
plot_pca(ax, df_eg_hell, c="coral", legend="Egypt Hellenistic", ec="blue", s=40, marker="o")

#plot_pca(ax, df_vill, c="red", legend="Andalusia Villaricos Punic", ec="darkred", s=50, marker="D")
#plot_pca(ax, df_ib, c="red", legend="Ibiza Punic", ec="sandybrown", s=70, marker="*")

#plot_pca(ax, df_sic, c="w", legend="Sicilly Punic", ec="blue", s=70, marker="s")
plot_pca(ax, df_vil, c="yellow", legend="Villamar Sardinian Punic", ec="darkred", s=49, marker="D")
plot_pca(ax, df_msr, c="pink", legend="Monte Sirai Sardinian Punic", ec="darkred", s=49, marker="D")

plot_pca(ax, df_sard, c="orange", legend="Tharros Sardinian Punic", ec="darkred", s=49, marker="s", text=False)

plot_pca(ax, df_vill, c="firebrick", legend="Villaricos Andalusia Punic", ec="darkred", s=49, marker="s", text=False)
plot_pca(ax, df_cad, c="lightcoral", legend="Cadiz Andalusia Punic", ec="darkred", s=49, marker="s", text=False)
plot_pca(ax, df_kerk, c="red", legend="Kerkouane Punic", ec="darkred", s=49, marker="s", text=False)


#plot_pca(ax, df_sic_him, c="lime", legend="Sicily Himera", s=90, marker="o", ec="k")
#plot_pca(ax, df_sic2, c="green", legend="Sicilly Punic", ec="k", s=70, marker="s")

locs, dfs = split_up_df(df = df_sic2, col="loc")
cs = ["red", "yellowgreen", "lime", "green", "lightgreen", 
      "darkgreen", "aquamarine", "blue", "black", "gray", "maroon"]
for i in range(len(locs)):
    plot_pca(ax, dfs[i], c=cs[i], legend=locs[i], s=90, marker="o", ec="k")
    


ax.legend(loc="upper right", fontsize=8)
ax.set_xlabel("PC 1")
ax.set_ylabel("PC 2")
ax.set_xlim([-0.025,0.15])
ax.set_ylim([-0.09,0.03])

if len(savepath) > 0:
    plt.savefig(savepath, bbox_inches = 'tight', 
                pad_inches = 0, dpi=600)
    print(f"Saved to: {savepath}")
    
plt.show()

# %% [markdown]
# # Plot context

# %%
#savepath="./figures/pca/west_med_punic_pca.pdf"
savepath="./figures/pca/west_med_context.png"
savepath=""

plt.figure(figsize=(8,8))
ax = plt.gca()

plot_pca_ho(ax, df_ho, c="lightgray", text=False)
plot_pca(ax, df_is, c="blue", legend="Israel Canaanite MLBA", ec="k", alpha=0.9)
plot_pca(ax, df_le, c="aqua", legend="Lebanon Canaanite MLBA", ec="k", alpha=0.9)
plot_pca(ax, df_isp, c="darkviolet", legend="Israel \"Phoenician\"", ec="k", alpha=0.9)
### Plot the Sardinian Samples
plot_pca(ax, df_sard_ba, c="lightgreen", legend="Sardinia BA", ec="k", s=40)
plot_pca(ax, df_tun, c="brown", legend="Tunisia N", ec="k", s=40)
plot_pca(ax, df_greek, c="gray", legend="Mycenean BA", ec="k", s=40)

plot_pca(ax, df_alg, c="k", legend="Algeria IA", s=40, ec="k")
plot_pca(ax, df_spain, c="green", legend="Spain IA", s=40, ec="k")

plot_pca(ax, df_sic_ia, c="orange", legend="Sicily Polizzello IA", s=40, ec="k")
plot_pca(ax, df_sic_mba, c="lime", legend="Sicily Motya MBA", s=40, ec="k")
plot_pca(ax, df_meno, c="gold", legend="Menorca LBA", ec="k", s=50, marker="o")

#plot_pca(ax, df_sic, c="w", legend="Sicilly Punic", ec="blue", s=70, marker="s")
#plot_pca(ax, df_sic2, c="coral", legend="Sicilly Punic2", ec="blue", s=70, marker="s")
#plot_pca(ax, df_sic_him, c="red", legend="Sicily Himera", s=90, marker="o", ec="k")

#plot_pca(ax, df_sic, c="k", legend="Sicilly Punic", ec="blue", s=70, marker=">")
#plot_pca(ax, df_sic2, c="coral", legend="Sicilly Punic2", ec="blue", s=70, marker=">")

ax.legend(loc="upper right", fontsize=10)
ax.set_xlabel("PC 1")
ax.set_ylabel("PC 2")
ax.set_xlim([-0.035,0.08])
ax.set_ylim([-0.07,0.035])

if len(savepath) > 0:
    plt.savefig(savepath, bbox_inches = 'tight', 
                pad_inches = 0, dpi=600)
    print(f"Saved to: {savepath}")
    
plt.show()

# %% [markdown]
# # PCA of Indivdiuals with African Ancestry

# %%
### Play with pulling out sample
df[df["pop"].str.contains("Africa")]["pop"].value_counts()
# Out:
# Italy_Sardinia_Punic_oNAfrica          4
# Italy_Sicily_unknown_oAfrican          2
# Spain_Vandal_Visigoth_oAfrican1        2
# Spain_Punic_oAfrican2                  2
# Italy_Sicily_LA_Jewish_oHighAfrican    1
# Tunisia_Punic_oAfrica                  1
# Italy_Sicily_MBA_oAfrican              1
# Italy_Sardinia_C_oAfrican              1
# Spain_BellBeaker_oAfrican              1
# Spain_EBA_Africa_all                   1
# Spain_Vandal_Visigoth_oAfrican2        1
# Spain_Punic_Roman_oAfrican3            1
# Name: pop, dtype: int64

# %%
df_alg_IA = get_sub_pops(df, pop_list=["Algeria_IA"])
df_alg_N = get_sub_pops(df, pop_list=["Algeria_N"])
df_ibero_m = get_sub_pops(df, pop_list=["Morocco_Iberomaurusian"])
df_mor_EN = get_sub_pops(df, pop_list=["Morocco_EN"])
df_mor_LN = get_sub_pops(df, pop_list=["Morocco_LN"])
df_sar_afr = get_sub_pops_exact(df, pop_list=["Italy_Sardinia_C_oAfrican"])
df_spain_afr = get_sub_pops_exact(df, pop_list=["Spain_BellBeaker_oAfrican"])
df_sicily_afr = get_sub_pops_exact(df, pop_list=["Italy_Sicily_MBA_oAfrican"])
# Out:
# Algeria_IA Found: 1/2043
# Algeria_N Found: 1/2043
# Morocco_Iberomaurusian Found: 7/2043
# Morocco_EN Found: 3/2043
# Morocco_LN Found: 3/2043
# Found ['Italy_Sardinia_C_oAfrican'] (exact): 1/2043
# Found ['Spain_BellBeaker_oAfrican'] (exact): 1/2043
# Found ['Italy_Sicily_MBA_oAfrican'] (exact): 1/2043

# %%
savepath="./figures/pca.v46/pca_afr_punic.png"
savepath=""

plt.figure(figsize=(8,8))
ax = plt.gca()

plot_pca(ax, df_ho, c="lightgray")

plot_pca(ax, df_is, c="blue", legend="Israel Canaanite MLBA", ec="k", alpha=0.9)
#plot_pca(ax, df_le, c="aqua", legend="Lebanon Canaanite MLBA", ec="k", alpha=0.9)
plot_pca(ax, df_isp, c="darkviolet", legend="Israel \"Phoenician\"", ec="k", alpha=0.9)
### Plot the Sardinian Samples
#plot_pca(ax, df_sard_ba, c="lightgreen", legend="Sardinia BA", ec="k", s=40)
plot_pca(ax, df_greek, c="gray", legend="Mycenean BA", ec="k", s=40)
plot_pca(ax, df_alg, c="k", legend="Algeria IA", s=40, marker="s", ec="k")
plot_pca(ax, df_spain, c="green", legend="Spain IA", s=40, ec="k")
plot_pca(ax, df_sic_ia, c="orange", legend="Sicily Polizzello IA", s=40, ec="k")

### Punic Samples
plot_pca(ax, df_sard, c="gray", legend="Non-Sicily Punic", ec="k", s=49, marker="o", text=False, alpha=0.9)
#plot_pca(ax, df_sard1, c="orange", legend="Tharros Sardinian Roman/Punic", ec="red", s=49, marker="s", text=False)
plot_pca(ax, df_vill, c="gray", legend="", ec="gray", s=49, marker="o", text=False)
plot_pca(ax, df_cad, c="gray", legend="", ec="gray", s=49, marker="o", text=False)
plot_pca(ax, df_kerk, c="gray", legend="", ec="gray", s=49, marker="o", text=False)


plot_pca(ax, df_eg_dyn, c="w", legend="Egypt Dynastic", ec="blue", s=40, marker="o")
plot_pca(ax, df_eg_hell, c="coral", legend="Egypt Hellenistic", ec="blue", s=40, marker="o")

plot_pca(ax, df_tun, c="brown", legend="Tunisia N", ec="k", s=60)
plot_pca(ax, df_alg_IA, c="red", legend="Algeria IA", ec="k", s=60)
plot_pca(ax, df_alg_N, c="k", legend="Algeria N", ec="k", s=60)
plot_pca(ax, df_ibero_m, c="cyan", legend="Morocco Iberomaurusian", ec="k", s=60)
plot_pca(ax, df_mor_EN, c="green", legend="Morocco EN", ec="k", s=60)
plot_pca(ax, df_mor_LN, c="lightgreen", legend="Morocco LN", ec="k", s=60)
plot_pca(ax, df_sar_afr, c="yellow", legend="Sardinia C Af. Outlier", ec="k", s=50, marker="D")
plot_pca(ax, df_spain_afr, c="orange", legend="Spain BB Af. Outlier", ec="k", s=50, marker="D")
plot_pca(ax, df_sicily_afr, c="red", legend="Sicily MBA Af. Outlier", ec="k", s=50, marker="D")



ax.legend(loc="upper right", fontsize=9)
ax.set_xlabel("PC 1")
ax.set_ylabel("PC 2")
ax.set_xlim([-0.035,0.12])
ax.set_ylim([-0.08,0.03])

plt.show()

# %%
df_vill.sort_values(by="pc2")
# Out:
#         iid       pc1       pc2       pc3       pc4  \
# 328  I18193 -0.045583 -0.050467 -0.053406 -0.047633
# 449  I18189 -0.031620 -0.042086 -0.027505 -0.024896
# 430  I18203 -0.005214 -0.014029  0.009392 -0.004817
# 394  I18201 -0.008545 -0.010712  0.006593 -0.006274
# 687  I18202 -0.006537 -0.008785  0.005073 -0.004806
# 375  I18199 -0.009633 -0.008367  0.010012  0.003589
#
#                                            pop Master ID  \
# 328                      Spain_Punic_oAfrican2    I18193
# 449                      Spain_Punic_oAfrican2    I18189
# 430                             Spain_Punic_o4    I18203
# 394  Spain_Punic_o.3rd.degree.relative.cluster    I18201
# 687  Spain_Punic_o.3rd.degree.relative.cluster    I18202
# 375  Spain_Punic_o.3rd.degree.relative.cluster    I18199
#
#                                           loc  n_cov_snp  mean_cov sex  \
# 328  Almería, Cuevas del Almazora, Villaricos   627577.0  0.522981   M
# 449  Almería, Cuevas del Almazora, Villaricos   399759.0  0.333132   M
# 430  Almería, Cuevas del Almazora, Villaricos   436696.0  0.363913   F
# 394  Almería, Cuevas del Almazora, Villaricos   501006.0  0.417505   M
# 687  Almería, Cuevas del Almazora, Villaricos    58646.0  0.048872   M
# 375  Almería, Cuevas del Almazora, Villaricos   538422.0  0.448685   M
#
#         age              contact
# 328  2218.0  Lalueza-Fox, Carles
# 449  2221.0  Lalueza-Fox, Carles
# 430  2225.0  Lalueza-Fox, Carles
# 394  2554.0  Lalueza-Fox, Carles
# 687  2350.0  Lalueza-Fox, Carles
# 375  2226.0  Lalueza-Fox, Carles

# %% [markdown]
# # Find close PCA matches

# %%
return_pca_matches(df, iid="I21966")[:50]
# Out:
#                   iid       pc1       pc2       pc3       pc4  \
# 404            I21966 -0.015149 -0.026914 -0.005899 -0.015163
# 386            I22232 -0.013772 -0.029237 -0.007023 -0.014216
# 579            VIL010 -0.017920 -0.028757 -0.008581 -0.015689
# 311            I24033 -0.013201 -0.025532 -0.006223 -0.011350
# 421            VIL007 -0.011331 -0.026037 -0.003551 -0.015784
# 446             I7261 -0.012812 -0.028070 -0.008997 -0.012656
# 177            I21850 -0.012999 -0.029891 -0.003100 -0.012966
# 245            I24044 -0.011441 -0.027520 -0.004281 -0.018817
# 169            I21858 -0.014664 -0.032437 -0.005946 -0.014399
# 322            I24031 -0.016188 -0.031231 -0.008517 -0.019641
# 570            I19194 -0.011900 -0.027793 -0.003332 -0.009347
# 480            I18195 -0.009912 -0.026818 -0.009309 -0.019121
# 718            I22094 -0.010137 -0.024594 -0.001498 -0.012616
# 589             I7454 -0.010129 -0.025016  0.001453 -0.014790
# 230            I21857 -0.015114 -0.028829 -0.005441 -0.006164
# 574             I7474 -0.021504 -0.021540 -0.010050 -0.012496
# 87             I12844 -0.013294 -0.022372 -0.006222 -0.023693
# 711             I7453 -0.013599 -0.028798 -0.016387 -0.014051
# 489            I18194 -0.020278 -0.033522 -0.010635 -0.020223
# 246             I4800 -0.011632 -0.019234  0.001828 -0.012824
# 112            I24557 -0.018629 -0.017180 -0.000689 -0.012415
# 663            VIL009 -0.012079 -0.029161 -0.007052 -0.026737
# 389            I24035 -0.006028 -0.023441  0.001846 -0.013993
# 606             I7263 -0.011196 -0.022272 -0.006865 -0.026606
# 40           SI-41.SG -0.007767 -0.024729 -0.013664 -0.022504
# 203            I12847 -0.004499 -0.021027 -0.000725 -0.015517
# 493        MS10614.SG -0.010788 -0.022263 -0.011259 -0.004611
# 708             I8039 -0.020824 -0.023003 -0.009957 -0.026188
# 755              M312 -0.021986 -0.017697 -0.001355 -0.021472
# 1599    LibyanJew1659 -0.020060 -0.016360  0.000694 -0.010978
# 268            I24192 -0.006596 -0.020231  0.003155 -0.017802
# 103            I12664 -0.010610 -0.016031  0.003637 -0.015376
# 498            I21194 -0.017148 -0.032435 -0.006410 -0.029172
# 756              M314 -0.019137 -0.012993 -0.001115 -0.014388
# 1580    LibyanJew1605 -0.018569 -0.013459  0.000269 -0.012871
# 1514    LibyanJew1263 -0.019369 -0.014764  0.001940 -0.011473
# 470            VIL011 -0.020347 -0.036925 -0.012824 -0.023513
# 669            I21971 -0.020389 -0.015487  0.003131 -0.018470
# 99             I24208 -0.019038 -0.034713 -0.011584 -0.027184
# 42           Mik15.SG -0.012699 -0.025651  0.008511 -0.021318
# 765              M358 -0.020939 -0.013769  0.001208 -0.014334
# 117            I12846 -0.002887 -0.021121  0.002238 -0.018033
# 309            I24676 -0.006766 -0.018460  0.004747 -0.012810
# 162            I22236 -0.007534 -0.021006 -0.000279 -0.026876
# 592            AMC001 -0.015473 -0.012556  0.000770 -0.019101
# 763              M344 -0.021389 -0.014709  0.003094 -0.014050
# 588            I21970 -0.021897 -0.012910 -0.000887 -0.013152
# 1510  TunisianJew1763 -0.019588 -0.014685  0.002391 -0.009318
# 712            I22090 -0.012283 -0.025290  0.000406 -0.000185
# 126           Pal7.SG -0.011523 -0.032284  0.008659 -0.020425
#
#                                   pop Master ID  \
# 404     Italy_Sardinia_Punic_oNAfrica    I21966
# 386                Italy_Sicily_Punic    I22232
# 579         Italy_Sardinia_IA_Punic_1    VIL010
# 311                     Tunisia_Punic    I24033
# 421         Italy_Sardinia_IA_Punic_1    VIL007
# 446                Italy_Sicily_Punic     I7261
# 177                Italy_Sicily_Punic    I21850
# 245                     Tunisia_Punic    I24044
# 169                Italy_Sicily_Punic    I21858
# 322                     Tunisia_Punic    I24031
# 570                Italy_Sicily_Punic    I19194
# 480          Spain_Vandal_Visigoth_o3    I18195
# 718     Italy_Sardinia_Punic_oNAfrica    I22094
# 589                Italy_Sicily_Punic     I7454
# 230                Italy_Sicily_Punic    I21857
# 574          Italy_Sicily_LA_Jewish_1     I7474
# 87                 Italy_Sicily_Punic    I12844
# 711                Italy_Sicily_Punic     I7453
# 489   Spain_Vandal_Visigoth_oAfrican1    I18194
# 246                Italy_Sicily_Punic     I4800
# 112                Italy_Sicily_Punic    I24557
# 663         Italy_Sardinia_IA_Punic_1    VIL009
# 389                     Tunisia_Punic    I24035
# 606                Italy_Sicily_Punic     I7263
# 40             Lebanon_Medieval_o1.SG     SI-41
# 203                Italy_Sicily_Punic    I12847
# 493                    Ibiza_Punic.SG   MS10614
# 708                Italy_Sicily_Punic     I8039
# 755                      Jew_Moroccan       NaN
# 1599              construct_WE_NA_PCA       NaN
# 268                     Tunisia_Punic    I24192
# 103                Italy_Sicily_Roman    I12664
# 498     Italy_Sicily_unknown_oAfrican    I21194
# 756                      Jew_Moroccan       NaN
# 1580              construct_WE_NA_PCA       NaN
# 1514              construct_WE_NA_PCA       NaN
# 470         Italy_Sardinia_IA_Punic_1    VIL011
# 669                Italy_Sicily_Punic    I21971
# 99                      Tunisia_Punic    I24208
# 42       Greece_AgeanPalatial_EMBA.SG     Mik15
# 765                      Jew_Moroccan       NaN
# 117                Italy_Sicily_Punic    I12846
# 309                Italy_Sicily_Punic    I24676
# 162                Italy_Sicily_Punic    I22236
# 592            Italy_Sardinia_Roman_o    AMC001
# 763                      Jew_Moroccan       NaN
# 588                Italy_Sicily_Punic    I21970
# 1510              construct_WE_NA_PCA       NaN
# 712     Italy_Sardinia_Punic_oNAfrica    I22090
# 126                    Greece_LN_2.SG      Pal7
#
#                                                     loc  n_cov_snp  mean_cov  \
# 404                                   Sardinia, Tharros   484013.0  0.403344
# 386                                       Sicily, Motya   516817.0  0.430681
# 579                              Villamar, VS, Villamar   173540.0  0.144617
# 311                                           Kerkouene   656738.0  0.547282
# 421                              Villamar, VS, Villamar   450084.0  0.375070
# 446             Sicily, Marsala, Lilybaeum, via Gramsci   403413.0  0.336178
# 177                     Sicily, Palermo, Caserma Tukory   790865.0  0.659054
# 245                                           Kerkouene   728947.0  0.607456
# 169   Sicily, Marsala, Lilybaeum, Necropoli Monumentale   796271.0  0.663559
# 322                                           Kerkouene   637992.0  0.531660
# 570                          Sicily, Selinunte, Manuzza   187082.0  0.155902
# 480            Almería, Cuevas del Almazora, Villaricos   350476.0  0.292063
# 718                                   Sardinia, Tharros    43695.0  0.036413
# 589          Sicily, Marsala, Lilybaeum, via De Gasperi   157678.0  0.131398
# 230               Sicily, Marsala, Lilybaeum, Tribunale   747880.0  0.623233
# 574                                      Sicily, Licata   181644.0  0.151370
# 87                                        Sicily, Motya   878085.0  0.731738
# 711          Sicily, Marsala, Lilybaeum, via De Gasperi    45050.0  0.037542
# 489            Almería, Cuevas del Almazora, Villaricos   338791.0  0.282326
# 246                                       Sicily, Motya   728366.0  0.606972
# 112                                       Sicily, Birgi   852370.0  0.710308
# 663                              Villamar, VS, Villamar    77589.0  0.064658
# 389                                           Kerkouene   510629.0  0.425524
# 606             Sicily, Marsala, Lilybaeum, via Gramsci   136415.0  0.113679
# 40                                                Sidon  1090200.0  0.908500
# 203                                       Sicily, Birgi   772871.0  0.644059
# 493   Balearic Islands, Ibiza, Saint Antoni de Portm...   335079.0  0.279232
# 708               Sicily, Marsala, Lilybaeum, via Berta    47237.0  0.039364
# 755                                        not assigned        NaN       NaN
# 1599                                       not assigned        NaN       NaN
# 268                                           Kerkouene   703537.0  0.586281
# 103                                       Sicily, Birgi   858959.0  0.715799
# 498                          Sicily, Selinunte, Manuzza   324275.0  0.270229
# 756                                        not assigned        NaN       NaN
# 1580                                       not assigned        NaN       NaN
# 1514                                       not assigned        NaN       NaN
# 470                              Villamar, VS, Villamar   366554.0  0.305462
# 669                                     Sicily, Marsala    73755.0  0.061463
# 99                                            Kerkouene   863075.0  0.719229
# 42                                                Agean  1084444.0  0.903703
# 765                                        not assigned        NaN       NaN
# 117               Sicily, Marsala, Lilybaeum, Tribunale   847219.0  0.706016
# 309                                       Sicily, Birgi   657839.0  0.548199
# 162                                       Sicily, Motya   800485.0  0.667071
# 592                           Alghero, SS, Aho M. Carru   153681.0  0.128068
# 763                                        not assigned        NaN       NaN
# 588                                     Sicily, Marsala   158217.0  0.131847
# 1510                                       not assigned        NaN       NaN
# 712                                   Sardinia, Tharros    45035.0  0.037529
# 126                                          Paliambela   839338.0  0.699448
#
#       sex     age               contact
# 404     F  2300.0      Luiselli, Donata
# 386     M  2403.0      Caramelli, David
# 579     F  2741.0         John Novembre
# 311     F  2400.0          Pinhasi, Ron
# 421     M  2409.0         John Novembre
# 446     M  2300.0           Sineo, Luca
# 177     M  2500.0          Gronau, Ilan
# 245     F  2400.0          Pinhasi, Ron
# 169     M  2500.0          Gronau, Ilan
# 322     M  2400.0          Pinhasi, Ron
# 570     M  2500.0          Gronau, Ilan
# 480     F  1420.0   Lalueza-Fox, Carles
# 718     M  2350.0      Luiselli, Donata
# 589     F  2160.0           Sineo, Luca
# 230     M  2500.0          Gronau, Ilan
# 574     M  1450.0           Sineo, Luca
# 87      M  2105.0          Gronau, Ilan
# 711     M  2300.0           Sineo, Luca
# 489     M  1470.0   Lalueza-Fox, Carles
# 246     F  2554.0           Sineo, Luca
# 112     F  2500.0          Gronau, Ilan
# 663     F  2400.0         John Novembre
# 389     M  2400.0          Pinhasi, Ron
# 606     F  2300.0           Sineo, Luca
# 40      M   710.0         HaberAJHG2018
# 203     F  2500.0          Gronau, Ilan
# 493     F  2217.0       Zalloua, Pierre
# 708     F  2300.0           Sineo, Luca
# 755   NaN     NaN                   NaN
# 1599  NaN     NaN                   NaN
# 268     F  2400.0          Pinhasi, Ron
# 103     F  1833.0          Gronau, Ilan
# 498     M  2500.0          Gronau, Ilan
# 756   NaN     NaN                   NaN
# 1580  NaN     NaN                   NaN
# 1514  NaN     NaN                   NaN
# 470     M  2754.0         John Novembre
# 669     M  2500.0      Luiselli, Donata
# 99      M  2400.0          Pinhasi, Ron
# 42      U  4250.0  Unterlander, Martina
# 765   NaN     NaN                   NaN
# 117     M  2500.0          Gronau, Ilan
# 309     F  2500.0          Gronau, Ilan
# 162     F  2528.0      Caramelli, David
# 592     F  1772.0         John Novembre
# 763   NaN     NaN                   NaN
# 588     F  2500.0      Luiselli, Donata
# 1510  NaN     NaN                   NaN
# 712     M  2350.0      Luiselli, Donata
# 126     F  6348.0       Burger, Joachim

# %%
return_pca_matches(df, iid="I18187")[:30]

# %%
idx
# Out:
# Int64Index([1952,  934,  149,  955,  948,  153,  954,  953,  947,  604,
#             ...
#             1457, 1454, 1458,   15,   22,   18, 1693, 1692, 1440, 1439],
#            dtype='int64', length=1899)

# %% [markdown]
# ### Area 51

# %%
df["iid"][df["iid"].str.contains("I22118")]
# Out:
# 1956    I22118
# Name: iid, dtype: object

# %%
df1 = df[df["pop"].str.contains("Sic")]
df1["pop"].value_counts()

# %%
df_sard

# %%
base_path = "/n/groups/reich/DAVID/V44/V44.0/v44.0_HO"
ind_path = base_path + ".ind"

df_ho = pd.read_csv(ind_path, delim_whitespace=True, header=None)
df_ho.columns=["iid", "sex", "clst"]
print(f"Loaded {len(df_ho)} Individuals")
# Out:
# Loaded 32828 Individuals

# %%
df_ho[df_ho["iid"].str.contains("I22118")]
# Out:
# Empty DataFrame
# Columns: [iid, pc1, pc2, pc3, pc4, pop, Master ID, n_cov_snp, mean_cov, sex]
# Index: []

# %%
df_meta[df_meta["iid"].str.contains("I22118")]
# Out:
#             iid Master ID        lat       lon     age region        study  \
# 6834     I22118    I22118  39.873496  8.441024  2300.0  Italy  Unpublished
# 13391  I22118_d    I22118  39.873496  8.441024  2300.0  Italy  Unpublished
#
#                        clst  mean_cov  n_cov_snp avg_cov_snp  include_alt  \
# 6834   Italy_Sardinia_Punic  0.683903     820684       5.509         True
# 13391  Italy_Sardinia_Punic  0.267762     321314       0.706         True
#
#       family sex
# 6834      ..   M
# 13391     ..   U

# %%
df_meta
