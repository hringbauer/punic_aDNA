# %% [markdown]
# # Prepare Eigenstrat files to run PCA with HO SNPs
# Extract and Merge in relevant populations

# %%
import numpy as np
import os  # For Saving to Folder
import pandas as pd
import matplotlib.pyplot as plt

import socket
import os as os
import sys as sys
import multiprocessing as mp
import itertools as it
from time import time

socket_name = socket.gethostname()
print(socket_name)

if socket_name.startswith("compute-"):
    print("HSM Computational partition detected.")
    path = "/n/groups/reich/hringbauer/git/punic_aDNA/"  # The Path on Midway Cluster
else:
    raise RuntimeWarning("Not compatible machine. Check!!")

os.chdir(path)  # Set the right Path (in line with Atom default)
# Show the current working directory. Should be HAPSBURG/Notebooks/ParallelRuns
print(os.getcwd())
print(f"CPU Count: {mp.cpu_count()}")
print(sys.version)
# Out:
# compute-a-17-76.o2.rc.hms.harvard.edu
# HSM Computational partition detected.
# /n/groups/reich/hringbauer/git/punic_aDNA
# CPU Count: 32
# 3.7.4 (default, Sep 11 2019, 11:24:51)
# [GCC 6.2.0]

# %% [markdown]
# # Helper Functions

# %%
def return_pops(df, string, col="clst", 
                output=False):
    """Return list of clusters that contain string."""
    df1 = df[df[col].str.contains(string)]
    if output:
        print(df1[col].value_counts())
    clsts = list(set(df1[col].values))
    print(f"Found #clsts labels containing {string}: {len(clsts)}")

    return clsts

def run_convertf(path_convertf = "./o2bin/convertf", parfile = "./parfiles/convertf.keep.par"):
    """Runs the Downsampling"""
    ! $path_convertf -p $parfile

# %% [markdown]
# # Load the .ind File

# %%
base_path = "/n/groups/reich/DAVID/V46/V46.3/v46.3_HO"
ind_path = base_path + ".ind"

df_ind = pd.read_csv(ind_path, delim_whitespace=True, header=None)
df_ind.columns=["iid", "sex", "clst"]
print(f"Loaded {len(df_ind)} Individuals")
# Out:
# Loaded 34764 Individuals

# %%
### Check if everything loaded
return_pops(df_ind, "Russia_Greek")

# %%
df_ind[df_ind["clst"].str.contains("Lebanon")]

# %% [markdown]
# # Definie what target populations to pull

# %% [markdown]
# ### Ancients

# %%
pops = ["Algeria", "Morocco", "Tunisia", "Punic", "Phoenician", "Spain_Vandal", "Spain_LBA",
        "Sardinia", "Ibiza", "Israel_MLBA", "Israel_LBA", "Ashkelon", "Sicily", "Hellenistic",
        "Israel_IA", "Israel_EIA", "Israel_Persian", "Gibraltar", "Lebanon",
        "Spain_EBA_Afric", "Spain_BellBeaker_oAfrican", "Spain_Greek",
        "Spain_Hellenistic", "Spain_IA", "Italy_Sardinia_C_oAfrican", 
        "Nigeria_IA", "Nigeria_Medieval", "Mallorca", "Menorca", 
        "Egypt_Hellenistic", "Egypt_Roman", "Egypt_Dynastic",
        "Greece_", "Russia_Greek"]

exclude_strings = ["_lc", "contam"]

clsts = [return_pops(df_ind, string=pop, 
                     output=False) for pop in pops]

clsts = [inner for ls in clsts for inner in ls]
# Out:
# Found #clsts labels containing Algeria: 5
# Found #clsts labels containing Morocco: 8
# Found #clsts labels containing Tunisia: 10
# Found #clsts labels containing Punic: 38
# Found #clsts labels containing Phoenician: 3
# Found #clsts labels containing Spain_Vandal: 4
# Found #clsts labels containing Spain_LBA: 5
# Found #clsts labels containing Sardinia: 69
# Found #clsts labels containing Ibiza: 1
# Found #clsts labels containing Israel_MLBA: 12
# Found #clsts labels containing Israel_LBA: 2
# Found #clsts labels containing Ashkelon: 4
# Found #clsts labels containing Sicily: 73
# Found #clsts labels containing Hellenistic: 32
# Found #clsts labels containing Israel_IA: 3
# Found #clsts labels containing Israel_EIA: 1
# Found #clsts labels containing Israel_Persian: 1
# Found #clsts labels containing Gibraltar: 2
# Found #clsts labels containing Lebanon: 15
# Found #clsts labels containing Spain_EBA_Afric: 3
# Found #clsts labels containing Spain_BellBeaker_oAfrican: 2
# Found #clsts labels containing Spain_Greek: 3
# Found #clsts labels containing Spain_Hellenistic: 4
# Found #clsts labels containing Spain_IA: 18
# Found #clsts labels containing Italy_Sardinia_C_oAfrican: 2
# Found #clsts labels containing Nigeria_IA: 1
# Found #clsts labels containing Nigeria_Medieval: 2
# Found #clsts labels containing Mallorca: 1
# Found #clsts labels containing Menorca: 3
# Found #clsts labels containing Egypt_Hellenistic: 5
# Found #clsts labels containing Egypt_Roman: 3
# Found #clsts labels containing Egypt_Dynastic: 5
# Found #clsts labels containing Greece_: 48
# Found #clsts labels containing Russia_Greek: 19

# %% [markdown]
# ### Moderns
# Get list of Human Origin Populations to keep

# %%
path_ho = "/n/groups/reich/hringbauer/git/punic_aDNA/parfiles/pca/construct_WE_NA_PCA.list"

df_ho = pd.read_csv(path_ho, header=None, sep=r"\s+", engine="python")
df_ho.columns=["iid", "pop"]
print(f"Loaded {len(df_ho)} Individuals")

pops = set(df_ho["pop"])
clsts1 = [p.rsplit("_", 1)[0] for p in pops]
l = [np.sum(df_ind["clst"].str.contains(p)) for p in clsts1]
assert(np.min(l)>0)
# Out:
# Loaded 1196 Individuals

# %% [markdown]
# # Prepare and save final pop list

# %%
exclude_strings = ["_lc", "contam", "_d"]

clsts = list(set(clsts).union(set(clsts1))) # Filter to unique Elements
print(f"Loaded {len(clsts)} Populations")

### Exclude Strings
for ex in exclude_strings:
    clsts = [c for c in clsts if ex not in c]
print(f"After Exclusion {len(clsts)} populations")

### Originally Loaded 379 Populations
# After Exclusion 289 populations
# Out:
# Loaded 430 Populations
# After Exclusion 350 populations

# %%
keep = np.array(clsts)
path_keep = "./parfiles/pca/keep_pops"
np.savetxt(path_keep, keep, fmt="%s")
print(f"Saved {len(keep)} population names to {path_keep}")
# Out:
# Saved 350 population names to ./parfiles/pca/keep_pops

# %% [markdown]
# # Run convertf
# Takes about 20 min for all individuals
#
# Check additional parameters in manually encoded parfile!!

# %%
# %%time
run_convertf(path_convertf = "/n/groups/reich/hringbauer/o2bin/convertf", 
             parfile = "./parfiles/pca/convertf.keep.par")
# Out:
# parameter file: ./parfiles/pca/convertf.keep.par
# BASE: /n/groups/reich/
# DIR: DAVID/V46/V46.1/v46.1_HO
# OUT: hringbauer/git/punic_aDNA/eigenstrat/punic1.v46_HO
# genotypename: /n/groups/reich//DAVID/V46/V46.1/v46.1_HO.geno
# snpname: /n/groups/reich//DAVID/V46/V46.1/v46.1_HO.snp
# indivname: /n/groups/reich//DAVID/V46/V46.1/v46.1_HO.ind
# genooutfilename: /n/groups/reich//hringbauer/git/punic_aDNA/eigenstrat/punic1.v46_HO.geno
# snpoutfilename: /n/groups/reich//hringbauer/git/punic_aDNA/eigenstrat/punic1.v46_HO.snp
# indoutfilename: /n/groups/reich//hringbauer/git/punic_aDNA/eigenstrat/punic1.v46_HO.ind
# outputformat: PACKEDANCESTRYMAP
# hashcheck: YES
# poplistname: /n/groups/reich//hringbauer/git/punic_aDNA/parfiles/pca/keep_pops
# ## /n/groups/reich/hringbauer/o2bin/convertf version: 5722
# read 1073741824 bytes
# read 2147483648 bytes
# read 3221225472 bytes
# read 4294967296 bytes
# read 5193506943 bytes
# packed geno read OK
# end of inpack
# before compress: snps: 597573 indivs: 34761
# after compress: snps: 597573 indivs: 2188
# numvalidind:   2188  maxmiss: 2188001
# packedancestrymap output
# numsnps output: 597573
# ##end of convertf:     1578.730 seconds cpu      368.038 Mbytes in use
# CPU times: user 41.3 s, sys: 8.71 s, total: 50.1 s
# Wall time: 26min 29s

# %% [markdown]
# # Modify the .ind file to have one population to project on in moderns

# %%
path_ind = "/n/groups/reich/hringbauer/git/punic_aDNA/eigenstrat/punic1.v46_HO.ind"
path_mod = "/n/groups/reich/hringbauer/git/punic_aDNA/eigenstrat/punic1.v46_HO_mod.ind"

df_ind = pd.read_csv(path_ind, header=None, sep=r"\s+", engine="python")
df_ind.columns = ["iid", "sex", "pop"]
iids = df_ho["iid"].values # Alissas original IIDs
idx = [iid in iids for iid in df_ind["iid"]]
print(f"Found {np.sum(idx)}/{len(idx)} HO individuals")

df_ind.loc[idx, "pop"]  = "construct_WE_NA_PCA" #df_ind.loc[idx, "pop"] + "_mod" 
df_ind.to_csv(path_mod, sep=" ", index=None, header=False)
print(f"Saved {len(df_ind)} overall individuals to {path_mod}")

### Sanity Check 
#idx = [p in pops for p in df_ind["pop"]] 
idx = [(p=="construct_WE_NA_PCA") for p in df_ind["pop"]] 
print(f"Found {np.sum(idx)}/{len(idx)} of Alissas _mod pops")
# in v45: 1196/2169
# Out:
# Found 1196/2188 HO individuals
# Saved 2188 overall individuals to /n/groups/reich/hringbauer/git/punic_aDNA/eigenstrat/punic1.v46_HO_mod.ind
# Found 1196/2188 of Alissas _mod pops

# %%
### Needed only for trouble shooting ###
found = [iid in df_ind["iid"].values for iid in df_ho["iid"]]
print(f"Found {np.sum(found)}/{len(found)} of Alissas _mod pops")
#df_ho[~np.array(found)]["pop"].value_counts() # Only for
# Out:
# Found 1196/1196 of Alissas _mod pops

# %%
df_ind["pop"].value_counts()
# Out:
# construct_WE_NA_PCA                  1196
# Italy_Sicily_Punic                     54
# Assyrian                               47
# Israel_MLBA                            35
# Tunisia_Punic                          28
#                                      ...
# Spain_Punic_Roman_oAfrican1             1
# Israel_IA_o                             1
# Italy_Sicily_BellBeaker_published       1
# Italy_Sicily_MBA_o2                     1
# Egypt_Dynastic                          1
# Name: pop, Length: 268, dtype: int64

# %%
df_ind[df_ind["pop"].str.contains("Tunisia_Ph")]

# %% [markdown]
# # And now sbatch the PCA script.
# Takes about 9h for 1000 extra samples
#
# See in `./parfiles/pca/`

# %% [markdown]
# # Area 51

# %% [markdown]
# ### Save Meta File

# %%
path_ho = "/n/groups/reich//hringbauer/git/punic_aDNA/eigenstrat/combined/punic.v46.3.ind"
df_ho = pd.read_csv(path_ho, header=None, sep=r"\s+", engine="python")
df_ho.columns = ["iid", "sex", "clst"]
df_meta = pd.read_csv("/n/groups/reich/hringbauer/Data/v46.3.anno.csv")
df_save = pd.merge(df_ho["iid"], df_meta, on="iid")
df_save = df_save.sort_values(by="clst")
df_save.to_csv("./data/meta/v46.3_punic_meta.tsv", sep="\t", index=False)

# %%
len(df_save)
# Out:
# 1223

# %%
# Out:
#                    iid  Master ID                                         loc  \
# 261      HGDP00673.SDG  HGDP00673                                          ..
# 262      HGDP00669.SDG  HGDP00669                                          ..
# 263      HGDP01072.SDG  HGDP01072                                          ..
# 264      HGDP01077.SDG  HGDP01077                                          ..
# 265      HGDP00666.SDG  HGDP00666                                          ..
# 266      HGDP01064.SDG  HGDP01064                                          ..
# 267      HGDP00665.SDG  HGDP00665                                          ..
# 247      HGDP01073.SDG  HGDP01073                                          ..
# 248      HGDP01065.SDG  HGDP01065                                          ..
# 249      HGDP01066.SDG  HGDP01066                                          ..
# 250      HGDP00670.SDG  HGDP00670                                          ..
# 251      HGDP01071.SDG  HGDP01071                                          ..
# 252      HGDP00668.SDG  HGDP00668                                          ..
# 253      HGDP00674.SDG  HGDP00674                                          ..
# 245      HGDP01074.SDG  HGDP01074                                          ..
# 254      HGDP01068.SDG  HGDP01068                                          ..
# 14    S_Sardinian-1.DG  HGDP01079                                    Sardinia
# 259      HGDP01067.SDG  HGDP01067                                          ..
# 258      HGDP01063.SDG  HGDP01063                                          ..
# 1150          Href.REF       Href                                          ..
# 1149         Chimp.REF      Chimp                                          ..
# 260      HGDP01069.SDG  HGDP01069                                          ..
# 15    S_Sardinian-2.DG  HGDP01078                                    Sardinia
# 270      HGDP01076.SDG  HGDP01076                                          ..
# 269      HGDP01078.SDG  HGDP01078                                          ..
# 268      HGDP01079.SDG  HGDP01079                                          ..
# 256      HGDP01070.SDG  HGDP01070                                          ..
# 255      HGDP01075.SDG  HGDP01075                                          ..
# 12    A_Sardinian-4.DG  HGDP00665                                          ..
# 13    B_Sardinian-3.DG  HGDP01076                                          ..
# 257      HGDP00667.SDG  HGDP00667                                          ..
# 246      HGDP00671.SDG  HGDP00671                                          ..
# 839             I23647     I23647                             Navarra, Aralar
# 1182             I1955      I1955                                  Ganj Dareh
# 103              I5430      I5430                       Sicily, Monte Petroso
# 207              I7766      I7766                             Sicily, Palermo
# 588             SNN003     SNN003  Sassari, SAS, San Nicola Necropoli Esterna
# 586             SNN001     SNN001  Sassari, SAS, San Nicola Necropoli Esterna
# 587             SNN002     SNN002  Sassari, SAS, San Nicola Necropoli Esterna
# 589             SNN004     SNN004  Sassari, SAS, San Nicola Necropoli Esterna
# 420           SI-45.SG      SI-45                                       Sidon
# 415           SI-39.SG      SI-39                                       Sidon
# 417           SI-41.SG      SI-41                                       Sidon
# 418           SI-42.SG      SI-42                                       Sidon
# 419           SI-44.SG      SI-44                                       Sidon
# 414           SI-38.SG      SI-38                                       Sidon
# 421           SI-47.SG      SI-47                                       Sidon
# 416           SI-40.SG      SI-40                                       Sidon
# 422           SI-53.SG      SI-53                                       Sidon
# 435             I15562     I15562                             Sicily, Baucina
#
#             lat        lon  age   region  \
# 261   40.000000   9.000000    0    Italy
# 262   40.000000   9.000000    0    Italy
# 263   40.000000   9.000000    0    Italy
# 264   40.000000   9.000000    0    Italy
# 265   40.000000   9.000000    0    Italy
# 266   40.000000   9.000000    0    Italy
# 267   40.000000   9.000000    0    Italy
# 247   40.000000   9.000000    0    Italy
# 248   40.000000   9.000000    0    Italy
# 249   40.000000   9.000000    0    Italy
# 250   40.000000   9.000000    0    Italy
# 251   40.000000   9.000000    0    Italy
# 252   40.000000   9.000000    0    Italy
# 253   40.000000   9.000000    0    Italy
# 245   40.000000   9.000000    0    Italy
# 254   40.000000   9.000000    0    Italy
# 14    40.000000   9.000000    0    Italy
# 259   40.000000   9.000000    0    Italy
# 258   40.000000   9.000000    0    Italy
# 1150        NaN        NaN    0       ..
# 1149        NaN        NaN    0       ..
# 260   40.000000   9.000000    0    Italy
# 15    40.000000   9.000000    0    Italy
# 270   40.000000   9.000000    0    Italy
# 269   40.000000   9.000000    0    Italy
# 268   40.000000   9.000000    0    Italy
# 256   40.000000   9.000000    0    Italy
# 255   40.000000   9.000000    0    Italy
# 12          NaN        NaN    0    Italy
# 13    40.000000   9.000000    0    Italy
# 257   40.000000   9.000000    0    Italy
# 246   40.000000   9.000000    0    Italy
# 839   42.993100  -2.076600  213    Spain
# 1182  34.450000  48.116000  389     Iran
# 103   38.055200  13.251310  423    Italy
# 207   38.116667  13.366667  471    Italy
# 588   40.726921   8.558378  481    Italy
# 586   40.726921   8.558378  603    Italy
# 587   40.726921   8.558378  604    Italy
# 589   40.726921   8.558378  674    Italy
# 420   33.560556  35.398056  698  Lebanon
# 415   33.560556  35.398056  702  Lebanon
# 417   33.560556  35.398056  710  Lebanon
# 418   33.560556  35.398056  725  Lebanon
# 419   33.560556  35.398056  800  Lebanon
# 414   33.560556  35.398056  800  Lebanon
# 421   33.560556  35.398056  800  Lebanon
# 416   33.560556  35.398056  800  Lebanon
# 422   33.560556  35.398056  851  Lebanon
# 435   37.917000  13.533000  950    Italy
#
#                                             study  \
# 261                          BergstromScience2020
# 262                          BergstromScience2020
# 263                          BergstromScience2020
# 264                          BergstromScience2020
# 265                          BergstromScience2020
# 266                          BergstromScience2020
# 267                          BergstromScience2020
# 247                          BergstromScience2020
# 248                          BergstromScience2020
# 249                          BergstromScience2020
# 250                          BergstromScience2020
# 251                          BergstromScience2020
# 252                          BergstromScience2020
# 253                          BergstromScience2020
# 245                          BergstromScience2020
# 254                          BergstromScience2020
# 14                              MallickNature2016
# 259                          BergstromScience2020
# 258                          BergstromScience2020
# 1150                                       Genome
# 1149                                       Genome
# 260                          BergstromScience2020
# 15                              MallickNature2016
# 270                          BergstromScience2020
# 269                          BergstromScience2020
# 268                          BergstromScience2020
# 256                          BergstromScience2020
# 255                          BergstromScience2020
# 12                               MeyerScience2012
# 13                              PrueferNature2013
# 257                          BergstromScience2020
# 246                          BergstromScience2020
# 839                                   Unpublished
# 1182                          LazaridisNature2016
# 103   Unpublished (Alissa broad Italian transect)
# 207   Unpublished (Alissa broad Italian transect)
# 588                MarcusNatureCommunications2020
# 586                MarcusNatureCommunications2020
# 587                MarcusNatureCommunications2020
# 589                MarcusNatureCommunications2020
# 420                                 HaberAJHG2018
# 415                                 HaberAJHG2018
# 417                                 HaberAJHG2018
# 418                                 HaberAJHG2018
# 419                                 HaberAJHG2018
# 414                                 HaberAJHG2018
# 421                                 HaberAJHG2018
# 416                                 HaberAJHG2018
# 422                                 HaberAJHG2018
# 435   Unpublished (Alissa broad Italian transect)
#
#                                  clst  mean_cov  n_cov_snp avg_cov_snp  \
# 261                     Sardinian.SDG  0.948883    1138660          ..
# 262                     Sardinian.SDG  0.948868    1138642          ..
# 263                     Sardinian.SDG  0.950858    1141030          ..
# 264                     Sardinian.SDG  0.948732    1138478          ..
# 265                     Sardinian.SDG  0.948562    1138275          ..
# 266                     Sardinian.SDG  0.948884    1138661          ..
# 267   Ignore_Sardinian(discovery).SDG  0.939764    1127717          ..
# 247                     Sardinian.SDG  0.950354    1140425          ..
# 248                     Sardinian.SDG  0.949574    1139489          ..
# 249                     Sardinian.SDG  0.949278    1139134          ..
# 250                     Sardinian.SDG  0.950675    1140810          ..
# 251                     Sardinian.SDG  0.950609    1140731          ..
# 252                     Sardinian.SDG  0.946200    1135440          ..
# 253                     Sardinian.SDG  0.949623    1139547          ..
# 245                     Sardinian.SDG  0.949539    1139447          ..
# 254                     Sardinian.SDG  0.950083    1140100          ..
# 14                       Sardinian.DG  0.932336    1118803       36.38
# 259                     Sardinian.SDG  0.949801    1139761          ..
# 258                     Sardinian.SDG  0.948777    1138533          ..
# 1150                         Href.REF  0.958866    1150639          ..
# 1149                        Chimp.REF  0.918702    1102442          ..
# 260                     Sardinian.SDG  0.949521    1139425          ..
# 15                       Sardinian.DG  0.932189    1118627       34.77
# 270                     Sardinian.SDG  0.947367    1136840          ..
# 269                     Sardinian.SDG  0.950803    1140964          ..
# 268                     Sardinian.SDG  0.950943    1141132          ..
# 256                     Sardinian.SDG  0.949953    1139944          ..
# 255                     Sardinian.SDG  0.949807    1139768          ..
# 12     Ignore_Sardinian(discovery).DG  0.958582    1150298       24.68
# 13                       Sardinian.DG  0.932658    1119189       39.48
# 257                     Sardinian.SDG  0.948402    1138083          ..
# 246                     Sardinian.SDG  0.950114    1140137          ..
# 839                          Spain_IA  0.668882     802659       8.895
# 1182          Iran_GanjDareh_Historic  0.653200     783840       4.231
# 103               Italy_Sicily_Modern  0.485186     582223       0.779
# 207               Italy_Sicily_Modern  0.653668     784401    1.401234
# 588           Italy_Sardinia_Medieval  0.338600     406320    0.510139
# 586           Italy_Sardinia_Medieval  0.105389     126467    0.120681
# 587           Italy_Sardinia_Medieval  0.115257     138309    0.133827
# 589           Italy_Sardinia_Medieval  0.187464     224957    0.224702
# 420               Lebanon_Medieval.SG  0.943294    1131953    3.600627
# 415            Lebanon_Medieval_o2.SG  0.444300     533160    0.609085
# 417            Lebanon_Medieval_o1.SG  0.908500    1090200     2.99926
# 418               Lebanon_Medieval.SG  0.446213     535456    0.609508
# 419            Lebanon_Medieval_o3.SG  0.342315     410778    0.427325
# 414               Lebanon_Medieval.SG  0.393918     472702    0.509888
# 421            Lebanon_Medieval_o2.SG  0.334629     401555    0.415769
# 416            Lebanon_Medieval_o5.SG  0.307534     369041    0.374014
# 422            Lebanon_Medieval_o4.SG  0.954276    1145131    4.363621
# 435              Italy_Sicily_Islamic  0.425291     510349    0.714039
#
#       include_alt                       family sex              contact
# 261          True  n/a (no relatives detected)   F                   ..
# 262          True  n/a (no relatives detected)   F                   ..
# 263          True  n/a (no relatives detected)   F                   ..
# 264          True  n/a (no relatives detected)   M                   ..
# 265          True  n/a (no relatives detected)   M                   ..
# 266          True  n/a (no relatives detected)   F                   ..
# 267          True  n/a (no relatives detected)   M                   ..
# 247          True  n/a (no relatives detected)   M                   ..
# 248          True  n/a (no relatives detected)   F                   ..
# 249          True  n/a (no relatives detected)   M                   ..
# 250          True  n/a (no relatives detected)   M                   ..
# 251          True  n/a (no relatives detected)   M                   ..
# 252          True  n/a (no relatives detected)   M                   ..
# 253          True  n/a (no relatives detected)   M                   ..
# 245          True  n/a (no relatives detected)   F                   ..
# 254          True  n/a (no relatives detected)   F                   ..
# 14           True  n/a (no relatives detected)   M                   ..
# 259          True  n/a (no relatives detected)   M                   ..
# 258          True  n/a (no relatives detected)   M                   ..
# 1150         True  n/a (no relatives detected)   M                   ..
# 1149         True  n/a (no relatives detected)   M                   ..
# 260          True  n/a (no relatives detected)   M                   ..
# 15           True  n/a (no relatives detected)   F                   ..
# 270          True  n/a (no relatives detected)   M                   ..
# 269          True  n/a (no relatives detected)   F                   ..
# 268          True  n/a (no relatives detected)   M                   ..
# 256          True  n/a (no relatives detected)   F                   ..
# 255          True  n/a (no relatives detected)   M                   ..
# 12           True  n/a (no relatives detected)   M                   ..
# 13           True  n/a (no relatives detected)   M                   ..
# 257          True  n/a (no relatives detected)   F                   ..
# 246          True  n/a (no relatives detected)   M                   ..
# 839          True                           ..   M  Lalueza-Fox, Carles
# 1182         True  n/a (no relatives detected)   F         Pinhasi, Ron
# 103          True  n/a (no relatives detected)   F         Pinhasi, Ron
# 207          True  n/a (no relatives detected)   M          Sineo, Luca
# 588          True  n/a (no relatives detected)   F        John Novembre
# 586          True  n/a (no relatives detected)   M        John Novembre
# 587          True  n/a (no relatives detected)   M        John Novembre
# 589          True  n/a (no relatives detected)   M        John Novembre
# 420          True  n/a (no relatives detected)   M        HaberAJHG2018
# 415          True  n/a (no relatives detected)   M        HaberAJHG2018
# 417          True  n/a (no relatives detected)   M        HaberAJHG2018
# 418          True  n/a (no relatives detected)   M        HaberAJHG2018
# 419          True  n/a (no relatives detected)   M        HaberAJHG2018
# 414          True  n/a (no relatives detected)   M        HaberAJHG2018
# 421          True  n/a (no relatives detected)   M        HaberAJHG2018
# 416          True  n/a (no relatives detected)   M        HaberAJHG2018
# 422          True  n/a (no relatives detected)   M        HaberAJHG2018
# 435          True  n/a (no relatives detected)   F  Lalueza-Fox, Carles
